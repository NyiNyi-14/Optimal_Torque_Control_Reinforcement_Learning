# %%
# CCS torque control, Efficiency priority control 
import time
from typing import Tuple, Optional, List, Type

import gymnasium as gym
from matplotlib.pylab import seed
import numpy as np
import torch as th
import torch.nn as nn
import matplotlib.pyplot as plt

from gymnasium import ObservationWrapper
from gymnasium.wrappers import TimeLimit
from gymnasium.spaces import Box

from stable_baselines3 import DDPG, TD3
from stable_baselines3.common.policies import BaseModel
from stable_baselines3.common.preprocessing import get_action_dim
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.utils import update_learning_rate
from stable_baselines3.td3.policies import Actor, TD3Policy

import gym_electric_motor as gem
from gym_electric_motor.physical_systems import ConstantSpeedLoad
from gym_electric_motor.physical_system_wrappers import DeadTimeProcessor

from dq_to_abc_action_processor import DqToAbcActionProcessor
from gym_electric_motor.reference_generators import MultipleReferenceGenerator, ConstReferenceGenerator, \
      WienerProcessReferenceGenerator, StepReferenceGenerator
from gym_electric_motor import RewardFunction

from gym_electric_motor.utils import set_state_array
import warnings
from scipy import signal
import random
import pickle
from stable_baselines3.common.noise import NormalActionNoise
from typing import Callable
import matplotlib.ticker as ticker
from cos_sin_processor import CosSinProcessor

# import gem_controllers as gc

# import tensorboard

# %%
# Modify Observation space to get flat vector instead of tuple
# that's why it is customized here
class FeatureWrapper(ObservationWrapper):
    """
    Wrapper class which wraps the environment to change its observation from a tuple to a flat vector.
    """
    def __init__(self, env):
        """
        Changes the observation space from a tuple to a flat vector
        
        Args:
            env(GEM env): GEM environment to wrap
        """
        super(FeatureWrapper, self).__init__(env)
        state_space = self.env.observation_space[0]
        ref_space = self.env.observation_space[1]
        # ref_space = Box(np.array([-1, -1]), np.array([1, 1]))

        new_low = np.concatenate((state_space.low,
                                  ref_space.low))
        new_high = np.concatenate((state_space.high,
                                   ref_space.high))
    
        self.observation_space = Box(new_low, new_high)

    def observation(self, observation):
        """
        Gets called at each return of an observation.
        
        """
        observation = np.concatenate((observation[0],
                                      observation[1],
                                      ))
        # print(f"Obs_check \n {observation}")
        return observation

# %%
class LastActionWrapper(gym.Wrapper):
    def __init__(self, env):
        super(LastActionWrapper, self).__init__(env)
        state_space = self.env.observation_space
        action_space = self.env.action_space

        # obs = "i_sd", "i_sq", "omega", "i_e", "cos", "sin", t ref, 3 actions (-1,-2,-3) <Torque C>
        new_low = np.concatenate((state_space.low,
                                  action_space.low))
        new_high = np.concatenate((state_space.high,
                                   action_space.high))

        self.observation_space = Box(new_low, new_high)

# fill last action with zeros
    def reset(self, seed = 42, **kwargs):
        super().reset(seed = seed)
        observation, info = self.env.reset(**kwargs)
        self.last_action = np.zeros(self.action_space.shape[0], dtype=np.float32)
        return np.concatenate((observation, self.last_action)), info

# put action to the last action
    def step(self, action):
        observation, reward, terminated, truncated, info = self.env.step(action)
        self.last_action = action
        observation[4] = 0.1 * observation[4] # Cos
        observation[5] = 0.1 * observation[5] # Sine
        return np.concatenate((observation, self.last_action)), reward, terminated, truncated, info

# %%
def efficiency(ele_P, mech_P, threshold=1e-10):
    # Replace zero values with a small threshold to avoid division by zero
    ele_P = np.where(ele_P == 0, threshold, ele_P)
    mech_P = np.where(mech_P == 0, threshold, mech_P)
    division = min([abs(ele_P), abs(mech_P)]) / max([abs(ele_P), abs(mech_P)])
    Effic = max(0, min(1, division))
    return float(Effic)

# %%
class CustomizedReward(RewardFunction):
    
    def __init__(self, reward_weights=None, normed_reward_weights=False, violation_reward=None,
                 gamma = 0.9, reward_power=1, bias=0.0):

        super().__init__()

        self._n = reward_power
        self._reward_weights = reward_weights
        self._state_length = None
        self._normed = normed_reward_weights
        self._gamma = gamma
        self._bias = bias
        self._violation_reward = violation_reward

    def set_modules(self, physical_system, reference_generator, constraint_monitor):
        super().set_modules(physical_system, reference_generator, constraint_monitor)
        ps = physical_system

        self._n = set_state_array(self._n, ps.state_names)
        referenced_states = reference_generator.referenced_states
        
        reward_weights = self._reward_weights
        self._reward_weights = set_state_array(reward_weights, ps.state_names)
        if sum(self._reward_weights) == 0:
            warnings.warn("All reward weights sum up to zero", Warning, stacklevel=2)
        rw_sum = sum(self._reward_weights)
        if self._normed:
            if self._bias == 'positive':
                self._bias = 1
            self._reward_weights = self._reward_weights / rw_sum
            self.reward_range = (-1 + self._bias, self._bias)
        else:
            if self._bias == 'positive':
                self._bias = rw_sum
            self.reward_range = (-rw_sum + self._bias, self._bias)
        if self._violation_reward is None:
            self._violation_reward = min(self.reward_range[0] / (1.0 - self._gamma), 0)
    
    # def reward(self, state, reference, k=None, action=None, violation_degree=0.0):
    #     return (1.0 - violation_degree) * self._wse_reward(state, reference) \
    #         + violation_degree * self._violation_reward
    
    def reward(self, state, reference, k=None, action=None, violation_degree=0.0):
        return (1.0 - violation_degree) * self._wse_reward(state, reference) \
            + violation_degree * self._wse_reward(state, reference)

    def _wse_reward(self, state, reference):
        T_tolerance = 0.1
        T_limit = 1
        T_error = abs(reference[1] - state[1])
        i_nominal = 0.8
        i_limit = 1
        i_f = state[7]
        i_applied = np.sqrt(state[5]**2 + state[6]**2)

        # Efficiency Calculation, no machine parameter is used
        stator_u = np.array([100])
        rotor_u = np.array([200])
        stator_i = np.array([31.25])
        rotor_i = np.array([6.25])
        torque_max = np.array([20])
        omega_max = np.array([7e+3*np.pi/30])

        physical_usd = state[11] * stator_u
        physical_usq = state[12] * stator_u
        physical_uf = state[13] * rotor_u
        physical_isd = state[5] * stator_i
        physical_isq = state[6] * stator_i
        physical_if = state[7] * rotor_i
        physical_t = state[1] * torque_max
        physical_sp = state[0] * omega_max

        stator_P = (3/2) * (physical_usd*physical_isd + physical_usq+physical_isq)
        rotor_P = physical_uf * physical_if
        ele_P = stator_P + rotor_P
        mech_P = physical_t * physical_sp

        Effic = efficiency(ele_P, mech_P)

        # Reward design
        # Excess Current Region [Reward > -1]
        if (i_applied > i_limit):
            R_tot = -0.1 - i_applied

        elif (i_f > i_limit):
            R_tot = -0.1 - i_f
        
        # Short-time overcurrent region [-0.1 < Reward < -0.05]
        elif (i_applied > i_nominal) and (i_applied < i_limit):
            R_tot = (1 - (i_applied-i_nominal)/(i_limit-i_nominal))*((1- self._gamma)/2) - (1- self._gamma)

        elif (i_f < 0): #[-0.15, -0.1]
        #     # R_tot = -(1- self._gamma) + i_f/20
            R_tot = (1 + i_f)*((1- self._gamma)/2) - ((1- self._gamma)/2) #[-0.05 < Reward < 0]

        # Unfavorable Efficiency Region (Skip now, id + or - is not straight forward here) [-0.05 < Reward < 0]
        elif (i_applied < i_nominal) and (state[5] < 0):
            R_tot = (1 + state[5])*((1- self._gamma)/2) - ((1- self._gamma)/2)

        # Desired Operating Region [0 < Reward < 0.05]
        elif (i_applied < i_nominal) and (T_error > T_tolerance):
            R_tot = (1- T_error/(2*T_limit)) * ((1- self._gamma)/2)
        
        elif (T_error < T_tolerance): #[0.05 < Reward < 0.1]
            R_tot = Effic*((1- self._gamma)/2) + ((1- self._gamma)/2)
        
        return R_tot

# %%
# write a costum callback to record the training progress
from stable_baselines3.common.callbacks import BaseCallback
class TrainingLogger(BaseCallback):
    """
    A custom callback that derives from ``BaseCallback``.

    :param verbose: Verbosity level: 0 for no output, 1 for info messages, 2 for debug messages
    """
    def __init__(self, verbose: int = 0):
        super().__init__(verbose)
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseAlgorithm
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env # type: VecEnv
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # num_timesteps = n_envs * n times env.step() was called
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = {}  # type: Dict[str, Any]
        # self.globals = {}  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger # type: stable_baselines3.common.logger.Logger
        # Sometimes, for event callback, it is useful
        # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]
        
    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        self.rewards = np.zeros(self.model._total_timesteps)

        pass

    def _on_rollout_start(self) -> None:
        """
        A rollout is the collection of environment interaction
        using the current policy.
        This event is triggered before collecting new samples.
        """
        pass

    def _on_step(self) -> bool:
        """
        This method will be called by the model after each call to `env.step()`.

        For child callback (of an `EventCallback`), this will be called
        when the event is triggered.

        :return: If the callback returns False, training is aborted early.
        """
        #print('1')
        self.rewards[self.num_timesteps - 1] = self.locals['rewards']
        self.logger.record("reward", np.mean(self.rewards[:self.num_timesteps+1]))

        return True

    def _on_rollout_end(self) -> None:
        """
        This event is triggered before updating the policy.
        """
        pass

    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        pass

# %%
motor_env_id = "Cont-TC-EESM-v0"
tau = 1e-4    # The duration of each sampling step
motor_type = 'EESM'

# %%
motor_parameter = {
        'p': 2,
        'l_d': 3.78e-3,
        'l_q': 1.21e-3,
        'l_m': 40e-3, 
        'l_e': 870e-3,
        'j_rotor': 0.3883,
        'r_s': 123e-3,
        'r_e': 15.6,
        'k': 0.057,
    }

limit_values = dict(
    omega = 7e+3*np.pi/30,
    i = 31.25,
    u = 200,
    u_e = 200,
    i_e = 6.25,
    torque = 20,
    )

nominal_values=dict(
    omega = 2e+3*np.pi/30,  # angular velocity in rad/s
    i = 25,                   # motor current in amps
    u = 200,                  # nominal voltage in volts
    u_e = 200,
    i_e = 5,
    torque = 15,
    )

eesm_init = {
    'states': {
        'i_sd' : 0.,
        'i_sq' : 0.,
        'i_e' : 0.,
        'epsilon' : 0.,
        }
    }

physical_system_wrappers = [
    # Wrapped directly around the physical system
    CosSinProcessor(angle='epsilon'),
    DqToAbcActionProcessor.make('EESM'),
    DeadTimeProcessor(steps=1) # Only use DeadTimeWrapper after you have implemented a last action concatinator for the state
    # Wrapped around the CosSinProcessor. Therefore, the generated states (cos and sin) can be accessed.
]

# load_init = {'states': {'omega': 2e+3*np.pi/30 * 0}}

load_init={'random_init': 'uniform', }
load = ConstantSpeedLoad(
    load_initializer=load_init 
)

T_generator = StepReferenceGenerator(reference_state = 'torque')
# T_generator = ConstReferenceGenerator('torque', 0.5)

reward_function = CustomizedReward(
    reward_weights = dict(torque = 1),
    reward_power = 1,
    violation_reward = -1, # not applicable here, it is defined in reward design
    gamma = 0.9, 
    normed_reward_weights = False # Otherwise weights will be normed automatically to sum up to 1.
    )

env = gem.make(  
    motor_env_id,
    # visualize the results
    # parameterize the PMSM and update limitations
    motor=dict(
        motor_parameter=motor_parameter,
        limit_values=limit_values,
        nominal_values=nominal_values,
        motor_initializer=eesm_init,
    ),
    # define the random initialisation for load and motor
    load=load,
    tau=tau,
    #ode_solver='euler',
    physical_system_wrappers=physical_system_wrappers, # Pass the Physical System Wrappers
    # state_filter=["i_sd", "i_sq", "omega", "i_e", "torque", "cos(epsilon)", "sin(epsilon)"], # this is connected to following index
    state_filter=["i_sd", "i_sq", "omega", "i_e", "cos(epsilon)", "sin(epsilon)"],
    supply=dict(u_nominal=200),
    reference_generator = T_generator,
    reward_function = reward_function
    )

env = TimeLimit(LastActionWrapper(FeatureWrapper(env)), max_episode_steps = 10000)
# Out:
# Transforming r_e, l_m and l_e to stator side.
# To specify stator-side quantities, make use of keys r_E, l_M and l_E instead.

# %%
def Noise_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def Decay_noise(_current_progress_remaining: float) -> float:

        if (_current_progress_remaining >= 0.75): # initial phase
            sigma = initial_value
        elif (_current_progress_remaining < 0.75) and (_current_progress_remaining >= 0.5): # exploration phase
            m = -2.8
            # c = 8 * initial_value # c = 2.4
            c = 2.4
            m_e = -5.6
            c_e = 4.8

            sigma_sd = (m * _current_progress_remaining) + c
            sigma_sq = (m * _current_progress_remaining) + c
            sigma_e = (m_e * _current_progress_remaining) + c_e
            sigma = np.concatenate((sigma_sd, sigma_sq, sigma_e))

        elif (_current_progress_remaining < 0.5): # exploitation phase
            coeff = initial_value/300 # A coefficient = 0.001
            coe_e = 0.002
            k = -13.82
            sigma_sd = coeff[0] * np.exp(-k * _current_progress_remaining)
            sigma_sq = coeff[1] * np.exp(-k * _current_progress_remaining)
            sigma_e = coe_e * np.exp(-k * _current_progress_remaining)
            sigma = np.concatenate((sigma_sd, sigma_sq, sigma_e))

        N_actions = env.action_space.shape[-1]
        action_noise = NormalActionNoise(mean=np.zeros(N_actions), sigma = sigma)

        return action_noise

    return Decay_noise

# %%
class CustomDDPG(DDPG):
    def __init__(self, policy, env, *args, actor_lr=1e-5, critic_lr=1e-4, action_noise, **kwargs):
    #def __init__(self, policy, env, *args, actor_lr=1e-5, critic_lr=1e-4, **kwargs):
        super().__init__(policy, env, *args, **kwargs)
        self.actor_lr = actor_lr
        self.critic_lr = critic_lr
        self.action_noise = action_noise(self._current_progress_remaining)
        # self.action_noise = ShapedOU(action_noise)
        
    def _update_learning_rate(self, optimizers):
        """
                Costum function to update actor and critic with different learning rates.
                Based on https://github.com/DLR-RM/stable-baselines3/issues/338
                """
        actor_optimizer, critic_optimizer = optimizers

        update_learning_rate(actor_optimizer, self.actor_lr)
        update_learning_rate(critic_optimizer, self.critic_lr)

# %%
def create_network(input_dim, hidden_sizes, output_dim, activations):
    """
    Create a neural network with customizable layers, sizes, and activation functions.

    Args:
    - input_dim (int): The size of the input layer.
    - hidden_sizes (list): List of integers representing the sizes of each hidden layer.
    - output_dim (int): The size of the output layer.
    - activations (list): List of tuples where each tuple contains the activation function
                          name as the first element and any parameters as subsequent elements.
                          Pass None for layers without activation.

    Returns:
    - network (nn.Sequential): The created neural network.
    """

    layers = []
    
    # Input layer
    #m = nn.Linear(20, 30) ==> 20 is input, 30 is output
    #input = torch.randn(128, 20) ==> 128 batch, 20 features
    #output = m(input)
    #print(output.size())
    #torch.Size([128, 30]) ==> 128 batch, 30 features

    layers.append(nn.Linear(input_dim, hidden_sizes[0])) # ???
    
    # Activation function for the first hidden layer
    if activations[0] is not None:
        activation, *params = activations[0]
        act_func = getattr(nn, activation)(*params)
        layers.append(act_func)

    # Hidden layers
    for i in range(1, len(hidden_sizes)):
        layers.append(nn.Linear(hidden_sizes[i - 1], hidden_sizes[i]))

        # Activation function
        if activations[i] is not None:
            activation, *params = activations[i]
            act_func = getattr(nn, activation)(*params)
            layers.append(act_func)

    # Output layer
    layers.append(nn.Linear(hidden_sizes[-1], output_dim))

    # Activation function for output layer
    if activations[-1] is not None:
        activation, *params = activations[-1]
        act_func = getattr(nn, activation)(*params)
        layers.append(act_func)

    return nn.Sequential(*layers)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

actor_activations = [('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('Tanh',)]
critic_activations = [('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), None]

actor_network = create_network(
    input_dim = state_dim,
    output_dim = action_dim,
    hidden_sizes =[128, 128, 128],
    activations=actor_activations)

critic_network = create_network(
    input_dim=state_dim + action_dim,
    output_dim=1,
    hidden_sizes= [128, 128, 128, 128, 128, 128, 128],
    activations=critic_activations)

# %%
class CustomActor(Actor):
    """
    Actor network (policy) for TD3.
    """
    def __init__(self, *args, **kwargs):
        super(CustomActor, self).__init__(*args, **kwargs)
        # Define custom network with Dropout
        # WARNING: it must end with a tanh activation to squash the output
        #self.mu = nn.Sequential(...)
        self.mu = actor_network

class CustomContinuousCritic(BaseModel):
    """
    Critic network(s) for DDPG/SAC/TD3.
    """
    def __init__(
        self,
        observation_space: gym.spaces.Space,
        action_space: gym.spaces.Space,
        net_arch: List[int],
        features_extractor: nn.Module,
        features_dim: int,
        activation_fn: Type[nn.Module] = nn.ReLU,
        normalize_images: bool = True,
        n_critics: int = 2,
        share_features_extractor: bool = True,
    ):
        super().__init__(
            observation_space,
            action_space,
            features_extractor=features_extractor,
            normalize_images=normalize_images,
        )

        action_dim = get_action_dim(self.action_space)

        self.share_features_extractor = share_features_extractor
        self.n_critics = n_critics
        self.q_networks = []
        for idx in range(n_critics):
            # q_net = create_mlp(features_dim + action_dim, 1, net_arch, activation_fn)
            # Define critic with Dropout here
            q_net = critic_network
            self.add_module(f"qf{idx}", q_net)
            self.q_networks.append(q_net)

    def forward(self, obs: th.Tensor, actions: th.Tensor) -> Tuple[th.Tensor, ...]:
        # Learn the features extractor using the policy loss only
        # when the features_extractor is shared with the actor
        with th.set_grad_enabled(not self.share_features_extractor):
            features = self.extract_features(obs, self.features_extractor)
        qvalue_input = th.cat([features, actions], dim=1)
        return tuple(q_net(qvalue_input) for q_net in self.q_networks)

    def q1_forward(self, obs: th.Tensor, actions: th.Tensor) -> th.Tensor:
        """
        Only predict the Q-value using the first network.
        This allows to reduce computation when all the estimates are not needed
        (e.g. when updating the policy in TD3).
        """
        with th.no_grad():
            features = self.extract_features(obs, self.features_extractor)
        return self.q_networks[0](th.cat([features, actions], dim=1))

class CustomTD3Policy(TD3Policy):
    def __init__(self, *args, **kwargs):
        #actor_network = kwargs.pop('actor_network')
        #critic_network = kwargs.pop('critic_network')
        
        super(CustomTD3Policy, self).__init__(*args, **kwargs)
        #self.actor_network = actor_network
        #self.critic_network = critic_network

    def make_actor(self, features_extractor: Optional[BaseFeaturesExtractor] = None) -> CustomActor:
        actor_kwargs = self._update_features_extractor(self.actor_kwargs, features_extractor)
        return CustomActor(**actor_kwargs).to(self.device)

    def make_critic(self, features_extractor: Optional[BaseFeaturesExtractor] = None) -> CustomContinuousCritic:
        critic_kwargs = self._update_features_extractor(self.critic_kwargs, features_extractor)
        return CustomContinuousCritic(**critic_kwargs).to(self.device)

TD3.policy_aliases["CustomTD3Policy"] = CustomTD3Policy

# %%
simulation_time = 90 # seconds
nb_steps = int(simulation_time//tau)
# nb_steps = 25600 # number of training steps
learning_starts = 10000 # memory warmup
buffer_size = nb_steps + learning_starts #number of old observation steps saved
train_freq = 1 # prediction network gets an update each train_freq's step
batch_size = 128 # mini batch size drawn at each update step
gamma = 0.9
verbose = 1 # verbosity of stable-basline's prints
lr_actor = 1e-5
lr_critic = 1e-4
# lr_actor = linear_schedule(1e-5)
# lr_critic = linear_schedule(1e-4)
# action_noise = 0.4
action_noise = Noise_schedule(np.array([0.3, 0.3, 0.6]))

# %%
from stable_baselines3.common.logger import configure

policy_kwargs = dict(optimizer_class=th.optim.Adam,)

agent = CustomDDPG("CustomTD3Policy", env, buffer_size=buffer_size, learning_starts=learning_starts ,train_freq=train_freq, 
            batch_size=batch_size, gamma=gamma, policy_kwargs=policy_kwargs, 
            verbose=verbose, actor_lr=lr_actor, critic_lr=lr_critic, action_noise = action_noise,)

start_time = time.time()

agent.learn(total_timesteps = nb_steps, callback=TrainingLogger())

total_time = time.time() - start_time
print(f"Batch size 1 total time: {total_time // 60} minutes, {total_time % 60} seconds")
# Out:
# Logging to /Users/nyinyia/Documents/GIT/log/20240909_WP5_Paper
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | reward             | -0.0629  |
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -1.42    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 2931     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 89       |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0491  |
# | rollout/           |          |
# |    ep_len_mean     | 33       |
# |    ep_rew_mean     | -1.63    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 3083     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 264      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0481  |
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -1.66    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 3113     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 414      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0493  |
# | rollout/           |          |
# |    ep_len_mean     | 33.3     |
# |    ep_rew_mean     | -1.64    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 3204     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 533      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0549  |
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | -1.63    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 3210     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 592      |
# ---------------------------------
# <ipython-input-6-a4df3d8b901e>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.rewards[self.num_timesteps - 1] = self.locals['rewards']
# <ipython-input-4-6d898e06df8b>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(Effic)
# ---------------------------------
# | reward             | -0.0559  |
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | -1.63    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 3201     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 698      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0538  |
# | rollout/           |          |
# |    ep_len_mean     | 31.1     |
# |    ep_rew_mean     | -1.67    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 3276     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 870      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0532  |
# | rollout/           |          |
# |    ep_len_mean     | 31.5     |
# |    ep_rew_mean     | -1.68    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 3333     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1008     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0538  |
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | -1.69    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 3320     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1131     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0561  |
# | rollout/           |          |
# |    ep_len_mean     | 29.5     |
# |    ep_rew_mean     | -1.66    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 3246     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1180     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0569  |
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | -1.64    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 3260     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1267     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0577  |
# | rollout/           |          |
# |    ep_len_mean     | 28.3     |
# |    ep_rew_mean     | -1.64    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 3288     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1360     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0588  |
# | rollout/           |          |
# |    ep_len_mean     | 27.6     |
# |    ep_rew_mean     | -1.62    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 3289     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1434     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 26.9     |
# |    ep_rew_mean     | -1.61    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 3293     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1507     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0601  |
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | -1.59    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 3289     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1584     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0601  |
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | -1.58    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 3310     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1681     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0592  |
# | rollout/           |          |
# |    ep_len_mean     | 26.7     |
# |    ep_rew_mean     | -1.58    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 3344     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1817     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0587  |
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -1.57    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 3356     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1926     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.06    |
# | rollout/           |          |
# |    ep_len_mean     | 26.1     |
# |    ep_rew_mean     | -1.57    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 3343     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1983     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 26.1     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 3338     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2092     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0592  |
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 3356     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2217     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.06    |
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 3353     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2281     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0606  |
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 3350     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2350     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 3337     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2401     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0619  |
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 3332     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2493     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0621  |
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 3334     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2575     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0607  |
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 3348     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2753     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0611  |
# | rollout/           |          |
# |    ep_len_mean     | 24.4     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 3357     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2850     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 3379     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3042     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0604  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 3377     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3098     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0608  |
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 3378     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3175     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0604  |
# | rollout/           |          |
# |    ep_len_mean     | 24.3     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 3388     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3297     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0609  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 3389     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3356     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0608  |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 3403     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3471     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3537     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 3400     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3621     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 3406     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3735     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 3406     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3823     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0608  |
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 3410     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3956     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0606  |
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 3414     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4072     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0607  |
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 3416     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4150     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 3407     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4202     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 3406     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4289     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 3411     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4386     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0619  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 3403     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4471     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0618  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 3406     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4574     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0621  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4637     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0622  |
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 3404     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4722     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0622  |
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4814     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0624  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 3402     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4884     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0623  |
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4980     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0626  |
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5043     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5097     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0635  |
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -1.46    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 3399     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5158     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0635  |
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 3396     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5254     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0638  |
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 3392     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5331     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0636  |
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 3397     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5445     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 3401     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5583     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 3402     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5692     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0626  |
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 3406     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5825     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0629  |
# | rollout/           |          |
# |    ep_len_mean     | 22.6     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 3405     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5882     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0632  |
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 3404     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5944     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0632  |
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -1.46    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 3405     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6022     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0632  |
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -1.46    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 3408     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6116     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0636  |
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -1.46    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 3404     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6172     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0636  |
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -1.46    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 3405     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6263     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0625  |
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 3421     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6488     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0623  |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 3424     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6598     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0624  |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 3423     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6692     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0625  |
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | -1.46    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 3423     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6769     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0624  |
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 3426     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6900     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0623  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 3425     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7014     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0625  |
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 3426     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7088     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0627  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 3425     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7160     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0628  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 3424     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7246     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0628  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 3423     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7342     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 3420     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7397     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0633  |
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 3417     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7468     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0635  |
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 3417     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7526     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 3417     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7602     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0638  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 3418     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7683     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 3418     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7784     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0635  |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 3419     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7898     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 3418     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7963     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.064   |
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 3414     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8023     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0638  |
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 3417     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8158     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 3416     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8259     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 3417     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8342     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0636  |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 3418     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8461     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0634  |
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 3423     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8597     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0635  |
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 3422     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8666     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 3420     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8735     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0633  |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 3422     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8903     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0634  |
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 3424     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8987     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0634  |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 3423     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9078     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0634  |
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 3422     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9167     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0636  |
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 3422     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9230     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0637  |
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 3422     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9323     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0636  |
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 3424     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9435     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0633  |
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 3430     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9577     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0631  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 3434     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9718     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0632  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 3429     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9791     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0635  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 3428     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9857     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0629  |
# | rollout/           |          |
# |    ep_len_mean     | 25.4     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 2987     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 10071    |
# | train/             |          |
# |    actor_loss      | 0.245    |
# |    critic_loss     | 0.0287   |
# |    n_updates       | 70       |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0614  |
# | rollout/           |          |
# |    ep_len_mean     | 28.6     |
# |    ep_rew_mean     | -1.58    |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 2172     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 10462    |
# | train/             |          |
# |    actor_loss      | 0.0592   |
# |    critic_loss     | 0.0176   |
# |    n_updates       | 461      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0328  |
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -1.18    |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 284      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 18549    |
# | train/             |          |
# |    actor_loss      | -0.122   |
# |    critic_loss     | 0.00141  |
# |    n_updates       | 8548     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0206  |
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 0.213    |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 227      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 23001    |
# | train/             |          |
# |    actor_loss      | -0.191   |
# |    critic_loss     | 0.000596 |
# |    n_updates       | 13000    |
# ---------------------------------
# ---------------------------------
# | reward             | -0.00648 |
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 3.06     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 190      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 30228    |
# | train/             |          |
# |    actor_loss      | -0.268   |
# |    critic_loss     | 0.00795  |
# |    n_updates       | 20227    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.00644  |
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | 7.84     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 164      |
# |    time_elapsed    | 261      |
# |    total_timesteps | 42965    |
# | train/             |          |
# |    actor_loss      | -0.336   |
# |    critic_loss     | 0.000313 |
# |    n_updates       | 32964    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0134   |
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | 12.3     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 154      |
# |    time_elapsed    | 349      |
# |    total_timesteps | 53913    |
# | train/             |          |
# |    actor_loss      | -0.318   |
# |    critic_loss     | 0.000799 |
# |    n_updates       | 43912    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0143   |
# | rollout/           |          |
# |    ep_len_mean     | 480      |
# |    ep_rew_mean     | 13.2     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 152      |
# |    time_elapsed    | 367      |
# |    total_timesteps | 56195    |
# | train/             |          |
# |    actor_loss      | -0.236   |
# |    critic_loss     | 0.000917 |
# |    n_updates       | 46194    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.015    |
# | rollout/           |          |
# |    ep_len_mean     | 503      |
# |    ep_rew_mean     | 14       |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 151      |
# |    time_elapsed    | 386      |
# |    total_timesteps | 58533    |
# | train/             |          |
# |    actor_loss      | -0.303   |
# |    critic_loss     | 0.000358 |
# |    n_updates       | 48532    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.016    |
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 15       |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 150      |
# |    time_elapsed    | 405      |
# |    total_timesteps | 60979    |
# | train/             |          |
# |    actor_loss      | -0.288   |
# |    critic_loss     | 0.00194  |
# |    n_updates       | 50978    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0169   |
# | rollout/           |          |
# |    ep_len_mean     | 548      |
# |    ep_rew_mean     | 16.1     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 149      |
# |    time_elapsed    | 424      |
# |    total_timesteps | 63306    |
# | train/             |          |
# |    actor_loss      | -0.292   |
# |    critic_loss     | 0.000533 |
# |    n_updates       | 53305    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0178   |
# | rollout/           |          |
# |    ep_len_mean     | 573      |
# |    ep_rew_mean     | 17.2     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 147      |
# |    time_elapsed    | 445      |
# |    total_timesteps | 65874    |
# | train/             |          |
# |    actor_loss      | -0.352   |
# |    critic_loss     | 0.00048  |
# |    n_updates       | 55873    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0186   |
# | rollout/           |          |
# |    ep_len_mean     | 596      |
# |    ep_rew_mean     | 18.2     |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 146      |
# |    time_elapsed    | 464      |
# |    total_timesteps | 68232    |
# | train/             |          |
# |    actor_loss      | -0.354   |
# |    critic_loss     | 0.000593 |
# |    n_updates       | 58231    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0192   |
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 19.1     |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 146      |
# |    time_elapsed    | 481      |
# |    total_timesteps | 70385    |
# | train/             |          |
# |    actor_loss      | -0.312   |
# |    critic_loss     | 0.000514 |
# |    n_updates       | 60384    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0197   |
# | rollout/           |          |
# |    ep_len_mean     | 639      |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 145      |
# |    time_elapsed    | 501      |
# |    total_timesteps | 72840    |
# | train/             |          |
# |    actor_loss      | -0.375   |
# |    critic_loss     | 0.000284 |
# |    n_updates       | 62839    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0204   |
# | rollout/           |          |
# |    ep_len_mean     | 662      |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 144      |
# |    time_elapsed    | 520      |
# |    total_timesteps | 75163    |
# | train/             |          |
# |    actor_loss      | -0.326   |
# |    critic_loss     | 0.000611 |
# |    n_updates       | 65162    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0211   |
# | rollout/           |          |
# |    ep_len_mean     | 687      |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 143      |
# |    time_elapsed    | 541      |
# |    total_timesteps | 77740    |
# | train/             |          |
# |    actor_loss      | -0.356   |
# |    critic_loss     | 0.00105  |
# |    n_updates       | 67739    |
# ---------------------------------
# ---------------------------------
# ...
# |    critic_loss     | 0.000618 |
# |    n_updates       | 754371   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0443   |
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | 76.2     |
# | time/              |          |
# |    episodes        | 1160     |
# |    fps             | 121      |
# |    time_elapsed    | 6309     |
# |    total_timesteps | 767652   |
# | train/             |          |
# |    actor_loss      | -0.495   |
# |    critic_loss     | 0.000312 |
# |    n_updates       | 757651   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0444   |
# | rollout/           |          |
# |    ep_len_mean     | 1.62e+03 |
# |    ep_rew_mean     | 82.9     |
# | time/              |          |
# |    episodes        | 1164     |
# |    fps             | 121      |
# |    time_elapsed    | 6439     |
# |    total_timesteps | 782680   |
# | train/             |          |
# |    actor_loss      | -0.557   |
# |    critic_loss     | 0.000327 |
# |    n_updates       | 772679   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0444   |
# | rollout/           |          |
# |    ep_len_mean     | 1.61e+03 |
# |    ep_rew_mean     | 82.9     |
# | time/              |          |
# |    episodes        | 1168     |
# |    fps             | 121      |
# |    time_elapsed    | 6463     |
# |    total_timesteps | 785465   |
# | train/             |          |
# |    actor_loss      | -0.552   |
# |    critic_loss     | 0.000153 |
# |    n_updates       | 775464   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0445   |
# | rollout/           |          |
# |    ep_len_mean     | 1.62e+03 |
# |    ep_rew_mean     | 83.2     |
# | time/              |          |
# |    episodes        | 1172     |
# |    fps             | 121      |
# |    time_elapsed    | 6495     |
# |    total_timesteps | 789084   |
# | train/             |          |
# |    actor_loss      | -0.486   |
# |    critic_loss     | 0.00123  |
# |    n_updates       | 779083   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0444   |
# | rollout/           |          |
# |    ep_len_mean     | 1.61e+03 |
# |    ep_rew_mean     | 82.3     |
# | time/              |          |
# |    episodes        | 1176     |
# |    fps             | 121      |
# |    time_elapsed    | 6514     |
# |    total_timesteps | 791311   |
# | train/             |          |
# |    actor_loss      | -0.544   |
# |    critic_loss     | 0.000501 |
# |    n_updates       | 781310   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.69e+03 |
# |    ep_rew_mean     | 87.7     |
# | time/              |          |
# |    episodes        | 1180     |
# |    fps             | 121      |
# |    time_elapsed    | 6619     |
# |    total_timesteps | 803347   |
# | train/             |          |
# |    actor_loss      | -0.596   |
# |    critic_loss     | 0.00155  |
# |    n_updates       | 793346   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.67e+03 |
# |    ep_rew_mean     | 86.3     |
# | time/              |          |
# |    episodes        | 1184     |
# |    fps             | 121      |
# |    time_elapsed    | 6652     |
# |    total_timesteps | 807134   |
# | train/             |          |
# |    actor_loss      | -0.538   |
# |    critic_loss     | 0.0136   |
# |    n_updates       | 797133   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.66e+03 |
# |    ep_rew_mean     | 85.8     |
# | time/              |          |
# |    episodes        | 1188     |
# |    fps             | 121      |
# |    time_elapsed    | 6678     |
# |    total_timesteps | 810143   |
# | train/             |          |
# |    actor_loss      | -0.499   |
# |    critic_loss     | 0.0124   |
# |    n_updates       | 800142   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.66e+03 |
# |    ep_rew_mean     | 85.3     |
# | time/              |          |
# |    episodes        | 1192     |
# |    fps             | 121      |
# |    time_elapsed    | 6700     |
# |    total_timesteps | 812708   |
# | train/             |          |
# |    actor_loss      | -0.537   |
# |    critic_loss     | 0.0213   |
# |    n_updates       | 802707   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.66e+03 |
# |    ep_rew_mean     | 85.3     |
# | time/              |          |
# |    episodes        | 1196     |
# |    fps             | 121      |
# |    time_elapsed    | 6728     |
# |    total_timesteps | 815906   |
# | train/             |          |
# |    actor_loss      | -0.477   |
# |    critic_loss     | 0.000387 |
# |    n_updates       | 805905   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.65e+03 |
# |    ep_rew_mean     | 84.7     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 121      |
# |    time_elapsed    | 6749     |
# |    total_timesteps | 818338   |
# | train/             |          |
# |    actor_loss      | -0.493   |
# |    critic_loss     | 0.000197 |
# |    n_updates       | 808337   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.65e+03 |
# |    ep_rew_mean     | 84.7     |
# | time/              |          |
# |    episodes        | 1204     |
# |    fps             | 121      |
# |    time_elapsed    | 6774     |
# |    total_timesteps | 821199   |
# | train/             |          |
# |    actor_loss      | -0.582   |
# |    critic_loss     | 0.0063   |
# |    n_updates       | 811198   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 79       |
# | time/              |          |
# |    episodes        | 1208     |
# |    fps             | 121      |
# |    time_elapsed    | 6793     |
# |    total_timesteps | 823329   |
# | train/             |          |
# |    actor_loss      | -0.565   |
# |    critic_loss     | 0.000382 |
# |    n_updates       | 813328   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 77.2     |
# | time/              |          |
# |    episodes        | 1212     |
# |    fps             | 121      |
# |    time_elapsed    | 6814     |
# |    total_timesteps | 825712   |
# | train/             |          |
# |    actor_loss      | -0.47    |
# |    critic_loss     | 0.011    |
# |    n_updates       | 815711   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0446   |
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 76.8     |
# | time/              |          |
# |    episodes        | 1216     |
# |    fps             | 121      |
# |    time_elapsed    | 6838     |
# |    total_timesteps | 828505   |
# | train/             |          |
# |    actor_loss      | -0.582   |
# |    critic_loss     | 0.000507 |
# |    n_updates       | 818504   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | 75.9     |
# | time/              |          |
# |    episodes        | 1220     |
# |    fps             | 121      |
# |    time_elapsed    | 6872     |
# |    total_timesteps | 832392   |
# | train/             |          |
# |    actor_loss      | -0.573   |
# |    critic_loss     | 0.000321 |
# |    n_updates       | 822391   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.43e+03 |
# |    ep_rew_mean     | 72.5     |
# | time/              |          |
# |    episodes        | 1224     |
# |    fps             | 121      |
# |    time_elapsed    | 6925     |
# |    total_timesteps | 838482   |
# | train/             |          |
# |    actor_loss      | -0.538   |
# |    critic_loss     | 0.000189 |
# |    n_updates       | 828481   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | 71.6     |
# | time/              |          |
# |    episodes        | 1228     |
# |    fps             | 121      |
# |    time_elapsed    | 6944     |
# |    total_timesteps | 840628   |
# | train/             |          |
# |    actor_loss      | -0.579   |
# |    critic_loss     | 0.000372 |
# |    n_updates       | 830627   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 65.9     |
# | time/              |          |
# |    episodes        | 1232     |
# |    fps             | 121      |
# |    time_elapsed    | 6967     |
# |    total_timesteps | 843304   |
# | train/             |          |
# |    actor_loss      | -0.546   |
# |    critic_loss     | 0.00218  |
# |    n_updates       | 833303   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 66       |
# | time/              |          |
# |    episodes        | 1236     |
# |    fps             | 121      |
# |    time_elapsed    | 6993     |
# |    total_timesteps | 846245   |
# | train/             |          |
# |    actor_loss      | -0.57    |
# |    critic_loss     | 0.000306 |
# |    n_updates       | 836244   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 64.9     |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 120      |
# |    time_elapsed    | 7018     |
# |    total_timesteps | 849073   |
# | train/             |          |
# |    actor_loss      | -0.518   |
# |    critic_loss     | 0.016    |
# |    n_updates       | 839072   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 63.4     |
# | time/              |          |
# |    episodes        | 1244     |
# |    fps             | 120      |
# |    time_elapsed    | 7061     |
# |    total_timesteps | 854061   |
# | train/             |          |
# |    actor_loss      | -0.56    |
# |    critic_loss     | 0.00599  |
# |    n_updates       | 844060   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 53       |
# | time/              |          |
# |    episodes        | 1248     |
# |    fps             | 120      |
# |    time_elapsed    | 7083     |
# |    total_timesteps | 856593   |
# | train/             |          |
# |    actor_loss      | -0.509   |
# |    critic_loss     | 0.000518 |
# |    n_updates       | 846592   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 973      |
# |    ep_rew_mean     | 47.2     |
# | time/              |          |
# |    episodes        | 1252     |
# |    fps             | 120      |
# |    time_elapsed    | 7103     |
# |    total_timesteps | 858803   |
# | train/             |          |
# |    actor_loss      | -0.553   |
# |    critic_loss     | 0.000578 |
# |    n_updates       | 848802   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0447   |
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 1256     |
# |    fps             | 120      |
# |    time_elapsed    | 7126     |
# |    total_timesteps | 861473   |
# | train/             |          |
# |    actor_loss      | -0.497   |
# |    critic_loss     | 0.000592 |
# |    n_updates       | 851472   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0448   |
# | rollout/           |          |
# |    ep_len_mean     | 992      |
# |    ep_rew_mean     | 48.4     |
# | time/              |          |
# |    episodes        | 1260     |
# |    fps             | 120      |
# |    time_elapsed    | 7174     |
# |    total_timesteps | 866880   |
# | train/             |          |
# |    actor_loss      | -0.54    |
# |    critic_loss     | 0.000442 |
# |    n_updates       | 856879   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0448   |
# | rollout/           |          |
# |    ep_len_mean     | 870      |
# |    ep_rew_mean     | 41.6     |
# | time/              |          |
# |    episodes        | 1264     |
# |    fps             | 120      |
# |    time_elapsed    | 7198     |
# |    total_timesteps | 869687   |
# | train/             |          |
# |    actor_loss      | -0.585   |
# |    critic_loss     | 0.000645 |
# |    n_updates       | 859686   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0448   |
# | rollout/           |          |
# |    ep_len_mean     | 929      |
# |    ep_rew_mean     | 44.8     |
# | time/              |          |
# |    episodes        | 1268     |
# |    fps             | 120      |
# |    time_elapsed    | 7274     |
# |    total_timesteps | 878349   |
# | train/             |          |
# |    actor_loss      | -0.559   |
# |    critic_loss     | 0.000272 |
# |    n_updates       | 868348   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0448   |
# | rollout/           |          |
# |    ep_len_mean     | 918      |
# |    ep_rew_mean     | 44.2     |
# | time/              |          |
# |    episodes        | 1272     |
# |    fps             | 120      |
# |    time_elapsed    | 7297     |
# |    total_timesteps | 880906   |
# | train/             |          |
# |    actor_loss      | -0.583   |
# |    critic_loss     | 0.000282 |
# |    n_updates       | 870905   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0448   |
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 45.3     |
# | time/              |          |
# |    episodes        | 1276     |
# |    fps             | 120      |
# |    time_elapsed    | 7334     |
# |    total_timesteps | 885187   |
# | train/             |          |
# |    actor_loss      | -0.628   |
# |    critic_loss     | 0.000493 |
# |    n_updates       | 875186   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0449   |
# | rollout/           |          |
# |    ep_len_mean     | 938      |
# |    ep_rew_mean     | 44.4     |
# | time/              |          |
# |    episodes        | 1280     |
# |    fps             | 120      |
# |    time_elapsed    | 7439     |
# |    total_timesteps | 897131   |
# | train/             |          |
# |    actor_loss      | -0.565   |
# |    critic_loss     | 0.00134  |
# |    n_updates       | 887130   |
# ---------------------------------
# Batch size 1 total time: 124.0 minutes, 25.035754919052124 seconds

# %%
obs, _ = env.reset(seed = 1)

# Take trained agent and loop over environment
i_sd = []
i_sq = []
omegas = []
i_f = []
torque_ref = []
action_stored = []
rewards_stored = []
# obs = ["i_sd", "i_sq", "omega", "i_e", "cos(epsilon)", "sin(epsilon)"], Tref, 3 actions

for i in range(10000):
    action, _states = agent.predict(obs, deterministic=True)

    obs, rewards, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    i_sd_idx = obs[0]
    i_sq_idx = obs[1]
    omega_idx = obs[2]
    i_f_idx = obs[3]
    torque_ref_idx = obs[-4]
    action_idx = obs[-3:]

    i_sd.append(i_sd_idx)
    i_sq.append(i_sq_idx)
    omegas.append(omega_idx)
    i_f.append(i_f_idx)
    torque_ref.append(torque_ref_idx)
    action_stored.append(action_idx)
    
    rewards_stored.append(rewards)

    if done:
        obs,_ = env.reset(seed = 1)

action_record = np.array(action_stored)
rewards_record = np.array(rewards_stored)
# Out:
# <ipython-input-4-6d898e06df8b>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(Effic)

# %%
motor_parameter = {
        'p': 2,
        'l_d': 3.78e-3,
        'l_q': 1.21e-3,
        'l_m': 40e-3, 
        'l_e': 870e-3,
        'j_rotor': 0.3883,
        'r_s': 123e-3,
        'r_e': 15.6,
        'k': 0.057,
    }

Supplied_Umax = 100
supp_uf = 200
real_usd = action_record[:,0] * Supplied_Umax
real_usq = action_record[:,1] * Supplied_Umax
real_uf = action_record[:,2] * supp_uf
Real_U = np.sqrt(real_usd**2 + real_usq**2) 

Supplied_Imax = np.array([31.25])
Supplied_Ifmax = np.array([6.25])
real_isd = i_sd * Supplied_Imax
real_isq = i_sq * Supplied_Imax
real_if = i_f * Supplied_Ifmax
Real_I = np.sqrt(real_isd**2 + real_isq**2)

# torque calculation manually, not available to agent
T_inter = np.zeros(len(i_sd))
T_relu = np.zeros(len(i_sd))
T_em = np.zeros(len(i_sd))

for i in range(len(i_sd)):
    T_inter[i] = motor_parameter['l_m'] * real_if[i] * real_isq[i]
    T_relu[i] = (motor_parameter['l_d'] - motor_parameter['l_q']) * real_isd[i] * real_isq[i]
    T_em[i] = (3/2) * motor_parameter['p'] * (T_inter[i] + T_relu[i])

T_max = np.array([20])
real_T  = T_em
real_Tref = torque_ref * T_max
Error = real_Tref - real_T

T_nom = T_em / T_max

S_max = np.array([7e+3*np.pi/30])
real_S = omegas * S_max

# Reward Manually, just for different validation profile
is_nominal = 0.8
T_lim = 1
gamma = 0.9
R_manual = np.zeros(len(i_sd))
T_E_check = np.zeros(len(i_sd))
i_s_app = np.zeros(len(i_sd))

for rr in range(len(i_sd)):
    T_E_check[rr] = abs(torque_ref[rr] - T_nom[rr])
    i_s_app[rr] = np.sqrt(i_sd[rr]**2 + i_sq[rr]**2)
    if (T_E_check[rr] > 0.1):
        R_manual[rr] = (1- T_E_check[rr]/(2*T_lim)) * ((1- gamma)/2)
    
    elif (T_E_check[rr] < 0.1):
        R_manual[rr] = (1-i_s_app[rr])*((1- gamma)/2) + ((1- gamma)/2)

# Efficiency
P_stator = (3/2) * (real_usd*real_isd + real_usq*real_isq) # stator power
P_rotor = real_uf * real_if # rotor power 
P_ele = P_stator + P_rotor # electrical power

# not used, just for comparison purpose
Ps_loss = (3/2) * Real_I**2 * motor_parameter['r_s']
Pr_loss = real_if**2 * motor_parameter['r_e']
P_losses = Ps_loss + Pr_loss

P_mech = real_T * real_S # mechanical power

P_total = P_ele - P_mech - P_losses

# From Losses, once again, not used
eff = np.zeros(len(P_mech))
for i in range(len(P_mech)):
    if (torque_ref[i] == 0): # motor
        eff[i] = 0

    elif (P_mech[i] > 0): # motor
        eff[i] = (abs(P_mech[i])/ (P_losses[i] + abs(P_mech[i])))

    elif (P_losses[i] > abs(P_mech[i])): # braking
        eff[i] = (P_losses[i] - abs(P_mech[i]))/ P_losses[i]

    elif (P_mech[i] < 0): # generator
        # eff[i] = abs(((-P_losses[i] + abs(P_mech[i]))/ (P_losses[i] + abs(P_mech[i]))))
        eff[i] = abs((P_mech[i] + P_losses[i]) / P_mech[i])

# From input vs output, used for further cases
eff2 = np.zeros(len(P_mech))
for j in range(len(P_mech)):
    if (torque_ref[j] == 0):
        eff2[j] = 0
    elif (P_ele[j] > 0 and P_mech[j] < 0) or (P_ele[j] < 0 and P_mech[j] > 0):
        eff2[j] = 0
    else:
        eff2[j] = max([0, min([1, min([abs(P_ele[j]), abs(P_mech[j])]) / max([abs(P_ele[j]), abs(P_mech[j])])])])

# MPTC method
i_f_num = np.array([5]) # nominal
i_stator = 25 # nominal 

p = motor_parameter['p']
l_d = motor_parameter['l_d']
l_q = motor_parameter['l_q']
l_M = 3 / 2 * motor_parameter['k'] * motor_parameter['l_m']
i_F_num = 2 / 3 / motor_parameter['k'] * i_f_num

var1 = -l_M * i_F_num
var2 = np.sqrt(l_M**2 * i_F_num**2 + 32 * i_stator**2 * (l_d - l_q)**2) 
var3 = 8 * i_stator * (l_d - l_q)

theta1 = np.zeros(len(i_f_num)) # MTPC angle

for i in range(len(i_f_num)):
    theta1[i] = np.arccos((var1[i] + var2[i])/ var3)

i_sd_num = i_stator * np.cos(theta1)
i_sq_num = i_stator * np.sin(theta1)
i_sq_negat = -i_stator * np.sin(theta1)

Tem_num = np.zeros(len(i_f_num))
Tem_negat = np.zeros(len(i_f_num))

for j in range(len(i_f_num)):
    Tem_num[j] = (3/2) * p * (l_M * i_F_num[j] * i_sq_num[j] + (l_d - l_q) * i_sd_num[j] * i_sq_num[j]) # positive torque 
    Tem_negat[j] = (3/2) * p * (l_M * i_F_num[j] * i_sq_negat[j] + (l_d - l_q) * i_sd_num[j] * i_sq_negat[j]) # negative torque

Tem_pos_nom = Tem_num/20 # nominal
Tem_neg_nom = Tem_negat/20 # nominal

visual = np.concatenate((np.array(i_f_num).reshape(-1,1), 
                         np.array(i_sd_num).reshape(-1,1), 
                         np.array(i_sq_num).reshape(-1,1), 
                         np.array(Tem_num).reshape(-1,1), 
                         np.array(Tem_negat).reshape(-1,1)), axis = 1)

# print(f"    i_f         i_sd       i_sq         Tem         Tem_neg \n {visual}")
# Out:
# <ipython-input-48-f76bbab8390d>:104: RuntimeWarning: invalid value encountered in scalar divide
#   eff2[j] = max([0, min([1, min([abs(P_ele[j]), abs(P_mech[j])]) / max([abs(P_ele[j]), abs(P_mech[j])])])])

# %%
# time_points = range(len(i_sd))
sampling = 1e-4
time_points = range(len(i_sd))
time_duration = np.arange(0, len(i_sd), 1000)
time_sec = (time_duration * sampling).round(2)
import seaborn as sns
sns.set_theme(context='notebook', style='white', palette='deep', font='Times New Roman', font_scale=1, color_codes=True, rc={'axes.linewidth': 2, 'grid.linewidth': 2})
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 12), sharex=True)

ax1.plot(time_points, i_sd, label='i_sd', color = 'red')
ax1.plot(time_points, i_sq, label='i_sq', color = 'green')
ax1.plot(time_points, i_f, label = 'i_f', color = 'blue')
ax1.set_ylabel(r'Current $[\frac{i}{i_{\text{max}}}]$')
ax1.legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol = 3)
ax1.grid()

ax2.plot(time_points, T_nom, label='T', color = 'red')
ax2.plot(time_points, torque_ref, label='T_ref', color = 'green')
ax2.fill_between(time_points, Tem_pos_nom, Tem_neg_nom, label = 'Available Torque Region', color = 'skyblue')
ax2.set_ylabel(r'Torque $[\frac{T}{T_{\text{max}}}]$')
ax2.legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol=3)
ax2.grid()

ax3.plot(time_points, omegas, label = r'$\omega$', color = 'red')
ax3.set_ylabel(r'Speed $[\frac{\omega}{\omega_{\text{max}}}]$')
ax3.legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol = 1)
ax3.grid()

ax4.plot(time_points, action_record[:,0], label='u_sd', color='red')
ax4.plot(time_points, action_record[:,1], label='u_sq', color='green')
ax4.plot(time_points, action_record[:,2], label='u_f', color='blue')
ax4.set_ylabel(r'Voltage $[\frac{u}{u_{\text{max}}}]$')
ax4.set_xlabel('Time step')
# ax4.set_ylim([-1,1])
ax4.set_xlim([0, len(i_sd)])
ax4.legend(loc='upper left', bbox_to_anchor=(0, -0.1),
          fancybox=True, shadow=True, ncol = 3)
ax4.grid()
# ax5.set_ylim([-1.5, 1.5])
# Adjust layout
plt.tight_layout()
plt.show()
