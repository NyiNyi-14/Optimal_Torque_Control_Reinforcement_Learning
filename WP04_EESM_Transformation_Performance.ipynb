# %%
# CCS torque control, Performance priority control 
import time
from typing import Tuple, Optional, List, Type

import gymnasium as gym
from matplotlib.pylab import seed
import numpy as np
import torch as th
import torch.nn as nn
import matplotlib.pyplot as plt

from gymnasium import ObservationWrapper
from gymnasium.wrappers import TimeLimit
from gymnasium.spaces import Box

from stable_baselines3 import DDPG, TD3
from stable_baselines3.common.policies import BaseModel
from stable_baselines3.common.preprocessing import get_action_dim
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.utils import update_learning_rate
from stable_baselines3.td3.policies import Actor, TD3Policy

import gym_electric_motor as gem
from gym_electric_motor.physical_systems import ConstantSpeedLoad
from gym_electric_motor.physical_system_wrappers import CosSinProcessor, DeadTimeProcessor, DqToAbcActionProcessor

from dq_to_abc_action_processor import DqToAbcActionProcessor # type: ignore
from gym_electric_motor.reference_generators import MultipleReferenceGenerator, ConstReferenceGenerator, \
      WienerProcessReferenceGenerator, StepReferenceGenerator
from gym_electric_motor import RewardFunction

from gym_electric_motor.utils import set_state_array
import warnings
from scipy import signal
import random
import pickle
from stable_baselines3.common.noise import NormalActionNoise
from typing import Callable
# import gem_controllers as gc

# import tensorboard

# %%
# Modify Observation space to get flat vector instead of tuple
# that's why it is customized here
class FeatureWrapper(ObservationWrapper):
    """
    Wrapper class which wraps the environment to change its observation from a tuple to a flat vector.
    """
    def __init__(self, env):
        """
        Changes the observation space from a tuple to a flat vector
        
        Args:
            env(GEM env): GEM environment to wrap
        """
        super(FeatureWrapper, self).__init__(env)
        state_space = self.env.observation_space[0]
        ref_space = self.env.observation_space[1]

        new_low = np.concatenate((state_space.low,
                                  ref_space.low))
        new_high = np.concatenate((state_space.high,
                                   ref_space.high))
    
        self.observation_space = Box(new_low, new_high)

    def observation(self, observation):
        """
        Gets called at each return of an observation.
        
        """
        observation = np.concatenate((observation[0],
                                      observation[1],
                                      ))
        # print(f"Obs_check \n {observation}")
        return observation

# %%
class LastActionWrapper(gym.Wrapper):
    def __init__(self, env):
        super(LastActionWrapper, self).__init__(env)
        state_space = self.env.observation_space
        action_space = self.env.action_space

        new_low = np.concatenate((state_space.low,
                                  action_space.low))
        new_high = np.concatenate((state_space.high,
                                   action_space.high))

        self.observation_space = Box(new_low, new_high)

# fill last action with zeros
    def reset(self, seed = 42, **kwargs):
        super().reset(seed = seed)
        observation, info = self.env.reset(**kwargs)
        self.last_action = np.zeros(self.action_space.shape[0], dtype=np.float32)
        return np.concatenate((observation, self.last_action)), info

# put action to the last action
    def step(self, action):
        observation, reward, terminated, truncated, info = self.env.step(action)
        self.last_action = action

        return np.concatenate((observation, self.last_action)), reward, terminated, truncated, info

# %%
class CustomizedReward(RewardFunction):
    
    def __init__(self, reward_weights=None, normed_reward_weights=False, violation_reward=None,
                 gamma = 0.9, reward_power=1, bias=0.0):

        super().__init__()

        self._n = reward_power
        self._reward_weights = reward_weights
        self._state_length = None
        self._normed = normed_reward_weights
        self._gamma = gamma
        self._bias = bias
        self._violation_reward = violation_reward

    def set_modules(self, physical_system, reference_generator, constraint_monitor):
        super().set_modules(physical_system, reference_generator, constraint_monitor)
        ps = physical_system

        self._n = set_state_array(self._n, ps.state_names)
        referenced_states = reference_generator.referenced_states
        
        reward_weights = self._reward_weights
        self._reward_weights = set_state_array(reward_weights, ps.state_names)
        if sum(self._reward_weights) == 0:
            warnings.warn("All reward weights sum up to zero", Warning, stacklevel=2)
        rw_sum = sum(self._reward_weights)
        if self._normed:
            if self._bias == 'positive':
                self._bias = 1
            self._reward_weights = self._reward_weights / rw_sum
            self.reward_range = (-1 + self._bias, self._bias)
        else:
            if self._bias == 'positive':
                self._bias = rw_sum
            self.reward_range = (-rw_sum + self._bias, self._bias)
        if self._violation_reward is None:
            self._violation_reward = min(self.reward_range[0] / (1.0 - self._gamma), 0)
    
    # def reward(self, state, reference, k=None, action=None, violation_degree=0.0):
    #     return (1.0 - violation_degree) * self._wse_reward(state, reference) \
    #         + violation_degree * self._violation_reward
    
    def reward(self, state, reference, k=None, action=None, violation_degree=0.0):
        return (1.0 - violation_degree) * self._wse_reward(state, reference) \
            + violation_degree * self._wse_reward(state, reference)

    # Reward design, same as WP03, just excitation current limitation here
    def _wse_reward(self, state, reference):
        T_tolerance = 0.1
        T_limit = 1
        T_error = abs(reference[1] - state[1])
        i_nominal = 0.8
        i_limit = 1
        i_f = state[7]
        i_applied = np.sqrt(state[5]**2 + state[6]**2)

        # Excess Current Region [Reward > -1]
        if (i_applied > i_limit):
            R_tot = -0.1 - i_applied

        # Excess Current Region [Reward > -1]
        elif (i_f > i_limit):
            R_tot = -0.1 - i_f

        # Short-time overcurrent region [-0.1 < Reward < -0.05]
        elif (i_applied > i_nominal) and (i_applied < i_limit):
            R_tot = (1 - (i_applied-i_nominal)/(i_limit-i_nominal))*((1- self._gamma)/2) - (1- self._gamma)

        elif (i_f < 0): #[-0.15, -0.1]
        #     # R_tot = -(1- self._gamma) + i_f/20
            R_tot = (1 + i_f)*((1- self._gamma)/2) - ((1- self._gamma)/2) #[-0.05 < Reward < 0]

        # Unfavorable Efficiency Region (Skip now, id + or - is not straight forward here) [-0.05 < Reward < 0]
        elif (i_applied < i_nominal) and (state[5] < 0):
            R_tot = (1 + state[5])*((1- self._gamma)/2) - ((1- self._gamma)/2)

        # Desired Operating Region [0 < Reward < 0.05]
        elif (i_applied < i_nominal) and (T_error > T_tolerance):
            R_tot = (1- T_error/(2*T_limit)) * ((1- self._gamma)/2)
        
        # Reference torque isoline [0.05 < Reward < 0.1]
        elif (i_applied < i_nominal) and (T_error < T_tolerance):
            R_tot = (1-i_applied)*((1- self._gamma)/2) + ((1- self._gamma)/2)

        return R_tot

# %%
# write a costum callback to record the training progress
from stable_baselines3.common.callbacks import BaseCallback
class TrainingLogger(BaseCallback):
    """
    A custom callback that derives from ``BaseCallback``.

    :param verbose: Verbosity level: 0 for no output, 1 for info messages, 2 for debug messages
    """
    def __init__(self, verbose: int = 0):
        super().__init__(verbose)
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseAlgorithm
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env # type: VecEnv
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # num_timesteps = n_envs * n times env.step() was called
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = {}  # type: Dict[str, Any]
        # self.globals = {}  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger # type: stable_baselines3.common.logger.Logger
        # Sometimes, for event callback, it is useful
        # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]
        
    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        self.rewards = np.zeros(self.model._total_timesteps)

        pass

    def _on_rollout_start(self) -> None:
        """
        A rollout is the collection of environment interaction
        using the current policy.
        This event is triggered before collecting new samples.
        """
        pass

    def _on_step(self) -> bool:
        """
        This method will be called by the model after each call to `env.step()`.

        For child callback (of an `EventCallback`), this will be called
        when the event is triggered.

        :return: If the callback returns False, training is aborted early.
        """
        #print('1')
        self.rewards[self.num_timesteps - 1] = self.locals['rewards']
        self.logger.record("reward", np.mean(self.rewards[:self.num_timesteps+1]))

        return True

    def _on_rollout_end(self) -> None:
        """
        This event is triggered before updating the policy.
        """
        pass

    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        pass

# %%
motor_env_id = "Cont-TC-EESM-v0"
tau = 1e-4    # The duration of each sampling step
motor_type = 'EESM'

# %%
motor_parameter = {
        'p': 2,
        'l_d': 3.78e-3,
        'l_q': 1.21e-3,
        'l_m': 40e-3, 
        'l_e': 870e-3,
        'j_rotor': 0.3883,
        'r_s': 123e-3,
        'r_e': 15.6,
        'k': 0.057,
    }

limit_values = dict(
    omega = 7e+3*np.pi/30,
    i = 31.25,
    u = 200,
    u_e = 200,
    i_e = 6.25,
    torque = 20,
    )

nominal_values=dict(
    omega = 2e+3*np.pi/30,  # angular velocity in rad/s
    i = 25,                   # motor current in amps
    u = 200,                  # nominal voltage in volts
    u_e = 200,
    i_e = 5,
    torque = 15,
    )

eesm_init = {
    'states': {
        'i_sd' : 0.,
        'i_sq' : 0.,
        'i_e' : 0.,
        'epsilon' : 0.,
        }
    }

physical_system_wrappers = [
    # Wrapped directly around the physical system
    CosSinProcessor(angle='epsilon'),
    DqToAbcActionProcessor.make('EESM'),
    DeadTimeProcessor(steps=1) # Only use DeadTimeWrapper after you have implemented a last action concatinator for the state
    # Wrapped around the CosSinProcessor. Therefore, the generated states (cos and sin) can be accessed.
]

# load_init = {'states': {'omega': 2e+3*np.pi/30 * 0}}

load_init={'random_init': 'uniform', }
load = ConstantSpeedLoad(
    load_initializer=load_init 
)

T_generator = StepReferenceGenerator(reference_state = 'torque')
# T_generator = ConstReferenceGenerator('torque', 0.5)

reward_function = CustomizedReward(
    reward_weights = dict(torque = 1),
    reward_power = 1, # Squared Error
    violation_reward = -1, # not applicable, violation reward will come from reward design above
    gamma = 0.9,
    normed_reward_weights = False # Otherwise weights will be normed automatically to sum up to 1.
    )

env = gem.make(  
    motor_env_id,
    motor=dict(
        motor_parameter=motor_parameter,
        limit_values=limit_values,
        nominal_values=nominal_values,
        motor_initializer=eesm_init,
    ),
    # define the random initialisation for load and motor
    load=load,
    tau=tau,
    #ode_solver='euler',
    physical_system_wrappers=physical_system_wrappers, # Pass the Physical System Wrappers
    # state_filter=["i_sd", "i_sq", "omega", "i_e", "torque", "cos(epsilon)", "sin(epsilon)"], # this is connected to following index
    state_filter=["i_sd", "i_sq", "omega", "i_e", "cos(epsilon)", "sin(epsilon)"], # this is connected to following index
    supply=dict(u_nominal=200),
    reference_generator = T_generator,
    reward_function = reward_function
    )

env = TimeLimit(LastActionWrapper(FeatureWrapper(env)), max_episode_steps = 10000)
# Out:
# Transforming r_e, l_m and l_e to stator side.
# To specify stator-side quantities, make use of keys r_E, l_M and l_E instead.

# %%
def Noise_schedule(initial_value: float) -> Callable[[float], float]:
    # noise deviation changing over time
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def Decay_noise(_current_progress_remaining: float) -> float:

        if (_current_progress_remaining >= 0.75): # initial phase
            sigma = initial_value
        elif (_current_progress_remaining < 0.75) and (_current_progress_remaining >= 0.5): # exploration phase
            m = -2.8
            # c = 8 * initial_value # c = 2.4
            c = 2.4

            m_e = -5.6
            c_e = 4.8

            sigma_sd = (m * _current_progress_remaining) + c
            sigma_sq = (m * _current_progress_remaining) + c
            sigma_e = (m_e * _current_progress_remaining) + c_e
            sigma = np.concatenate((sigma_sd, sigma_sq, sigma_e))

        elif (_current_progress_remaining < 0.5): # exploitation phase
            coeff = initial_value/300 # A coefficient = 0.001
            coe_e = 0.002
            k = -13.82
            sigma_sd = coeff[0] * np.exp(-k * _current_progress_remaining)
            sigma_sq = coeff[1] * np.exp(-k * _current_progress_remaining)
            sigma_e = coe_e * np.exp(-k * _current_progress_remaining)
            sigma = np.concatenate((sigma_sd, sigma_sq, sigma_e))

        N_actions = env.action_space.shape[-1]
        action_noise = NormalActionNoise(mean=np.zeros(N_actions), sigma = sigma)

        return action_noise

    return Decay_noise

# %%
class CustomDDPG(DDPG):
    def __init__(self, policy, env, *args, actor_lr=1e-5, critic_lr=1e-4, action_noise, **kwargs):
    #def __init__(self, policy, env, *args, actor_lr=1e-5, critic_lr=1e-4, **kwargs):
        super().__init__(policy, env, *args, **kwargs)
        self.actor_lr = actor_lr
        self.critic_lr = critic_lr
        self.action_noise = action_noise(self._current_progress_remaining)
        # self.action_noise = ShapedOU(action_noise)
        
    def _update_learning_rate(self, optimizers):
        """
                Costum function to update actor and critic with different learning rates.
                Based on https://github.com/DLR-RM/stable-baselines3/issues/338
                """
        actor_optimizer, critic_optimizer = optimizers

        update_learning_rate(actor_optimizer, self.actor_lr)
        update_learning_rate(critic_optimizer, self.critic_lr)

# %%
def create_network(input_dim, hidden_sizes, output_dim, activations):
    """
    Create a neural network with customizable layers, sizes, and activation functions.

    Args:
    - input_dim (int): The size of the input layer.
    - hidden_sizes (list): List of integers representing the sizes of each hidden layer.
    - output_dim (int): The size of the output layer.
    - activations (list): List of tuples where each tuple contains the activation function
                          name as the first element and any parameters as subsequent elements.
                          Pass None for layers without activation.

    Returns:
    - network (nn.Sequential): The created neural network.
    """

    layers = []
    
    # Input layer

    #m = nn.Linear(20, 30) ==> 20 is input, 30 is output
    #input = torch.randn(128, 20) ==> 128 batch, 20 features
    #output = m(input)
    #print(output.size())
    #torch.Size([128, 30]) ==> 128 batch, 30 features

    layers.append(nn.Linear(input_dim, hidden_sizes[0])) # ???
    
    # Activation function for the first hidden layer
    if activations[0] is not None:
        activation, *params = activations[0]
        act_func = getattr(nn, activation)(*params)
        layers.append(act_func)

    # Hidden layers
    for i in range(1, len(hidden_sizes)):
        layers.append(nn.Linear(hidden_sizes[i - 1], hidden_sizes[i]))

        # Activation function
        if activations[i] is not None:
            activation, *params = activations[i]
            act_func = getattr(nn, activation)(*params)
            layers.append(act_func)

    # Output layer
    layers.append(nn.Linear(hidden_sizes[-1], output_dim))

    # Activation function for output layer
    if activations[-1] is not None:
        activation, *params = activations[-1]
        act_func = getattr(nn, activation)(*params)
        layers.append(act_func)

    return nn.Sequential(*layers)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

actor_activations = [('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('Tanh',)]
critic_activations = [('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), ('LeakyReLU', 0.2), None]

actor_network = create_network(
    input_dim = state_dim,
    output_dim = action_dim,
    hidden_sizes =[128, 128, 128],
    activations=actor_activations)

critic_network = create_network(
    input_dim=state_dim + action_dim,
    output_dim=1,
    hidden_sizes= [128, 128, 128, 128, 128, 128, 128],
    activations=critic_activations)

# %%
class CustomActor(Actor):
    """
    Actor network (policy) for TD3.
    """
    def __init__(self, *args, **kwargs):
        super(CustomActor, self).__init__(*args, **kwargs)
        # Define custom network with Dropout
        # WARNING: it must end with a tanh activation to squash the output
        #self.mu = nn.Sequential(...)
        self.mu = actor_network

class CustomContinuousCritic(BaseModel):
    """
    Critic network(s) for DDPG/SAC/TD3.
    """
    def __init__(
        self,
        observation_space: gym.spaces.Space,
        action_space: gym.spaces.Space,
        net_arch: List[int],
        features_extractor: nn.Module,
        features_dim: int,
        activation_fn: Type[nn.Module] = nn.ReLU,
        normalize_images: bool = True,
        n_critics: int = 2,
        share_features_extractor: bool = True,
    ):
        super().__init__(
            observation_space,
            action_space,
            features_extractor=features_extractor,
            normalize_images=normalize_images,
        )

        action_dim = get_action_dim(self.action_space)

        self.share_features_extractor = share_features_extractor
        self.n_critics = n_critics
        self.q_networks = []
        for idx in range(n_critics):
            # q_net = create_mlp(features_dim + action_dim, 1, net_arch, activation_fn)
            # Define critic with Dropout here
            q_net = critic_network
            self.add_module(f"qf{idx}", q_net)
            self.q_networks.append(q_net)

    def forward(self, obs: th.Tensor, actions: th.Tensor) -> Tuple[th.Tensor, ...]:
        # Learn the features extractor using the policy loss only
        # when the features_extractor is shared with the actor
        with th.set_grad_enabled(not self.share_features_extractor):
            features = self.extract_features(obs, self.features_extractor)
        qvalue_input = th.cat([features, actions], dim=1)
        return tuple(q_net(qvalue_input) for q_net in self.q_networks)

    def q1_forward(self, obs: th.Tensor, actions: th.Tensor) -> th.Tensor:
        """
        Only predict the Q-value using the first network.
        This allows to reduce computation when all the estimates are not needed
        (e.g. when updating the policy in TD3).
        """
        with th.no_grad():
            features = self.extract_features(obs, self.features_extractor)
        return self.q_networks[0](th.cat([features, actions], dim=1))

class CustomTD3Policy(TD3Policy):
    def __init__(self, *args, **kwargs):
        #actor_network = kwargs.pop('actor_network')
        #critic_network = kwargs.pop('critic_network')
        
        super(CustomTD3Policy, self).__init__(*args, **kwargs)
        #self.actor_network = actor_network
        #self.critic_network = critic_network

    def make_actor(self, features_extractor: Optional[BaseFeaturesExtractor] = None) -> CustomActor:
        actor_kwargs = self._update_features_extractor(self.actor_kwargs, features_extractor)
        return CustomActor(**actor_kwargs).to(self.device)

    def make_critic(self, features_extractor: Optional[BaseFeaturesExtractor] = None) -> CustomContinuousCritic:
        critic_kwargs = self._update_features_extractor(self.critic_kwargs, features_extractor)
        return CustomContinuousCritic(**critic_kwargs).to(self.device)

TD3.policy_aliases["CustomTD3Policy"] = CustomTD3Policy

# %%
simulation_time = 90 # seconds
nb_steps = int(simulation_time//tau)
# nb_steps = 25600 # number of training steps
learning_starts = 10000 # memory warmup
buffer_size = nb_steps + learning_starts #number of old observation steps saved
train_freq = 1 # prediction network gets an update each train_freq's step
batch_size = 128 # mini batch size drawn at each update step
gamma = 0.9
verbose = 1 # verbosity of stable-basline's prints
lr_actor = 1e-5
lr_critic = 1e-4
# n_actions = env.action_space.shape[-1]
# action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.3 * np.ones(n_actions))
action_noise = Noise_schedule(np.array([0.3, 0.3, 0.6]))

# %%
from stable_baselines3.common.logger import configure

policy_kwargs = dict(optimizer_class=th.optim.Adam,)

agent = CustomDDPG("CustomTD3Policy", env, buffer_size=buffer_size, learning_starts=learning_starts ,train_freq=train_freq, 
            batch_size=batch_size, gamma=gamma, policy_kwargs=policy_kwargs, 
            verbose=verbose, actor_lr=lr_actor, critic_lr=lr_critic, action_noise = action_noise)

start_time = time.time()

agent.learn(total_timesteps = nb_steps, callback=TrainingLogger())

total_time = time.time() - start_time
print(f"Batch size 1 total time: {total_time // 60} minutes, {total_time % 60} seconds")
# Out:
# Logging to /Users/nyinyia/Documents/GIT/log/20240815_WP4_NT1_4
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | reward             | -0.0582  |
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -1.57    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 2320     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 107      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0553  |
# | rollout/           |          |
# |    ep_len_mean     | 27.8     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 2372     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 222      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.057   |
# | rollout/           |          |
# |    ep_len_mean     | 26.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 2338     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 318      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0542  |
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 2355     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 439      |
# ---------------------------------
# <ipython-input-5-a4df3d8b901e>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.rewards[self.num_timesteps - 1] = self.locals['rewards']
# ---------------------------------
# | reward             | -0.0587  |
# | rollout/           |          |
# |    ep_len_mean     | 25.3     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 2301     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 506      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0605  |
# | rollout/           |          |
# |    ep_len_mean     | 24.3     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 2279     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 583      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0627  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.47    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 2262     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 657      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0601  |
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 2256     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 800      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0624  |
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 2254     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 870      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 2260     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 986      |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0619  |
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 2265     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1080     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.061   |
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 2276     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1192     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 25.3     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 2293     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1317     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0591  |
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 2303     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1431     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0594  |
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 2310     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1531     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0611  |
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 2305     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1583     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0611  |
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 2308     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1663     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 2310     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1761     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0623  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 2301     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1815     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.062   |
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 2307     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1921     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 2310     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2028     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0625  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 2307     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2090     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 2315     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2219     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0626  |
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 2310     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2296     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0628  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 2307     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2380     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0621  |
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 2312     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2505     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0629  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 2307     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2568     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 2311     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2659     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0626  |
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 2317     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2768     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 2317     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2850     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0629  |
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 2322     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2949     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0628  |
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 2328     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3072     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0631  |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 2328     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3145     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.064   |
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 2324     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3183     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0628  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 2335     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3342     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0628  |
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 2339     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3442     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.063   |
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 2342     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3525     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0626  |
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 2338     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3642     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0619  |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 2344     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3778     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.062   |
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 2346     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3878     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0619  |
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 2350     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4004     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 2352     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4125     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 2359     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4267     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 2356     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4326     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0616  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 2357     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4432     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0616  |
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 2357     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4524     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 2358     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4636     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 2357     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4702     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 2355     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4801     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0611  |
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 2359     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4937     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 2358     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5023     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0614  |
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 2359     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5120     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 25.8     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 2362     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5242     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0611  |
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 2366     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5366     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 2366     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5444     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0604  |
# | rollout/           |          |
# |    ep_len_mean     | 26.9     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 2374     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5636     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0602  |
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 2378     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5752     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 27.6     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 2383     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 5900     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 28.3     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 2385     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6012     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0602  |
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 2382     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6057     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0603  |
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 2382     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6151     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0603  |
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 2383     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6252     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0606  |
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 2383     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6318     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0607  |
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 2383     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6409     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0607  |
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 2383     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6507     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0603  |
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 2386     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6637     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0605  |
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 2385     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6711     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0605  |
# | rollout/           |          |
# |    ep_len_mean     | 25.4     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 2386     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6811     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0608  |
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 2385     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6879     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0604  |
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 2387     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7035     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 2392     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7233     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0596  |
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 2393     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7347     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 2393     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7446     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0596  |
# | rollout/           |          |
# |    ep_len_mean     | 27.6     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 2394     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7556     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0595  |
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 2396     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7677     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 2392     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7755     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0596  |
# | rollout/           |          |
# |    ep_len_mean     | 27.6     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 2382     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7881     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 27.5     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 2384     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 7990     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 2384     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8081     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0597  |
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 2385     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8188     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 2385     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8273     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0599  |
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | -1.54    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 2384     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8343     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0601  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 2382     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8413     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0602  |
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 2382     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8504     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0604  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.53    |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 2380     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8567     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0604  |
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 2380     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8658     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0605  |
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 2380     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8738     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0608  |
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 2379     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8785     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.061   |
# | rollout/           |          |
# |    ep_len_mean     | 24.4     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 2377     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8849     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0609  |
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 2376     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8956     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 2375     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9020     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0611  |
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 2375     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9135     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0612  |
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 2374     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9228     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0614  |
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 2373     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9296     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -1.51    |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 2373     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9370     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 2372     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9443     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0618  |
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 2371     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 9508     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0618  |
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 2372     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 9607     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0617  |
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 2371     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 9716     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0615  |
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 2374     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 9862     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0613  |
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -1.49    |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 2375     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 9995     |
# ---------------------------------
# ---------------------------------
# | reward             | -0.0598  |
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 1641     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 10399    |
# | train/             |          |
# |    actor_loss      | 0.0205   |
# |    critic_loss     | 0.0367   |
# |    n_updates       | 398      |
# ---------------------------------
# ---------------------------------
# | reward             | 0.00339  |
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | 5.96     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 212      |
# |    time_elapsed    | 165      |
# |    total_timesteps | 35160    |
# | train/             |          |
# |    actor_loss      | -0.297   |
# |    critic_loss     | 0.00113  |
# |    n_updates       | 25159    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0117   |
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 10.3     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 222      |
# |    time_elapsed    | 209      |
# |    total_timesteps | 46616    |
# | train/             |          |
# |    actor_loss      | -0.375   |
# |    critic_loss     | 0.000717 |
# |    n_updates       | 36615    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0182   |
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | 15.7     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 226      |
# |    time_elapsed    | 263      |
# |    total_timesteps | 59599    |
# | train/             |          |
# |    actor_loss      | -0.402   |
# |    critic_loss     | 0.00123  |
# |    n_updates       | 49598    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0237   |
# | rollout/           |          |
# |    ep_len_mean     | 661      |
# |    ep_rew_mean     | 22.6     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 231      |
# |    time_elapsed    | 321      |
# |    total_timesteps | 74347    |
# | train/             |          |
# |    actor_loss      | -0.419   |
# |    critic_loss     | 0.000332 |
# |    n_updates       | 64346    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0288   |
# | rollout/           |          |
# |    ep_len_mean     | 829      |
# |    ep_rew_mean     | 31.3     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 233      |
# |    time_elapsed    | 390      |
# |    total_timesteps | 91218    |
# | train/             |          |
# |    actor_loss      | -0.476   |
# |    critic_loss     | 0.000228 |
# |    n_updates       | 81217    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0313   |
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 39.1     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 235      |
# |    time_elapsed    | 461      |
# |    total_timesteps | 108791   |
# | train/             |          |
# |    actor_loss      | -0.49    |
# |    critic_loss     | 0.000595 |
# |    n_updates       | 98790    |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0334   |
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 46.1     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 236      |
# |    time_elapsed    | 516      |
# |    total_timesteps | 122507   |
# | train/             |          |
# |    actor_loss      | -0.448   |
# |    critic_loss     | 0.000642 |
# |    n_updates       | 112506   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0338   |
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 47.7     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 237      |
# |    time_elapsed    | 530      |
# |    total_timesteps | 125835   |
# | train/             |          |
# |    actor_loss      | -0.459   |
# |    critic_loss     | 0.000528 |
# |    n_updates       | 115834   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0341   |
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 237      |
# |    time_elapsed    | 550      |
# |    total_timesteps | 130961   |
# | train/             |          |
# |    actor_loss      | -0.472   |
# |    critic_loss     | 0.00107  |
# |    n_updates       | 120960   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.036    |
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 57.1     |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 239      |
# |    time_elapsed    | 601      |
# |    total_timesteps | 143814   |
# | train/             |          |
# |    actor_loss      | -0.446   |
# |    critic_loss     | 0.00111  |
# |    n_updates       | 133813   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0369   |
# | rollout/           |          |
# |    ep_len_mean     | 1.44e+03 |
# |    ep_rew_mean     | 61.7     |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 239      |
# |    time_elapsed    | 637      |
# |    total_timesteps | 152876   |
# | train/             |          |
# |    actor_loss      | -0.473   |
# |    critic_loss     | 0.000973 |
# |    n_updates       | 142875   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.037    |
# | rollout/           |          |
# |    ep_len_mean     | 1.48e+03 |
# |    ep_rew_mean     | 63.5     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 240      |
# |    time_elapsed    | 653      |
# |    total_timesteps | 156840   |
# | train/             |          |
# |    actor_loss      | -0.483   |
# |    critic_loss     | 0.000227 |
# |    n_updates       | 146839   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0372   |
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 65       |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 240      |
# |    time_elapsed    | 666      |
# |    total_timesteps | 160162   |
# | train/             |          |
# |    actor_loss      | -0.47    |
# |    critic_loss     | 0.00034  |
# |    n_updates       | 150161   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0374   |
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 66.6     |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 240      |
# |    time_elapsed    | 679      |
# |    total_timesteps | 163218   |
# | train/             |          |
# |    actor_loss      | -0.486   |
# |    critic_loss     | 0.00277  |
# |    n_updates       | 153217   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0375   |
# | rollout/           |          |
# |    ep_len_mean     | 1.57e+03 |
# |    ep_rew_mean     | 68       |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 240      |
# |    time_elapsed    | 692      |
# |    total_timesteps | 166462   |
# | train/             |          |
# |    actor_loss      | -0.486   |
# |    critic_loss     | 0.000281 |
# |    n_updates       | 156461   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0377   |
# | rollout/           |          |
# |    ep_len_mean     | 1.6e+03  |
# |    ep_rew_mean     | 69.5     |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 240      |
# |    time_elapsed    | 704      |
# |    total_timesteps | 169422   |
# | train/             |          |
# |    actor_loss      | -0.476   |
# |    critic_loss     | 0.00043  |
# |    n_updates       | 159421   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0378   |
# | rollout/           |          |
# |    ep_len_mean     | 1.63e+03 |
# |    ep_rew_mean     | 70.8     |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 240      |
# |    time_elapsed    | 716      |
# |    total_timesteps | 172374   |
# | train/             |          |
# |    actor_loss      | -0.498   |
# |    critic_loss     | 0.000211 |
# |    n_updates       | 162373   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0379   |
# | rollout/           |          |
# |    ep_len_mean     | 1.66e+03 |
# |    ep_rew_mean     | 72.2     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 240      |
# |    time_elapsed    | 727      |
# |    total_timesteps | 175130   |
# | train/             |          |
# |    actor_loss      | -0.478   |
# |    critic_loss     | 0.00121  |
# |    n_updates       | 165129   |
# ---------------------------------
# ---------------------------------
# ...
# |    critic_loss     | 0.000489 |
# |    n_updates       | 393813   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0465   |
# | rollout/           |          |
# |    ep_len_mean     | 1.56e+03 |
# |    ep_rew_mean     | 84.2     |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 242      |
# |    time_elapsed    | 1692     |
# |    total_timesteps | 410474   |
# | train/             |          |
# |    actor_loss      | -0.546   |
# |    critic_loss     | 0.000415 |
# |    n_updates       | 400473   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0468   |
# | rollout/           |          |
# |    ep_len_mean     | 1.68e+03 |
# |    ep_rew_mean     | 91.2     |
# | time/              |          |
# |    episodes        | 664      |
# |    fps             | 242      |
# |    time_elapsed    | 1753     |
# |    total_timesteps | 425708   |
# | train/             |          |
# |    actor_loss      | -0.616   |
# |    critic_loss     | 0.00071  |
# |    n_updates       | 415707   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.047    |
# | rollout/           |          |
# |    ep_len_mean     | 1.69e+03 |
# |    ep_rew_mean     | 92.5     |
# | time/              |          |
# |    episodes        | 668      |
# |    fps             | 242      |
# |    time_elapsed    | 1788     |
# |    total_timesteps | 434474   |
# | train/             |          |
# |    actor_loss      | -0.616   |
# |    critic_loss     | 0.000834 |
# |    n_updates       | 424473   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0474   |
# | rollout/           |          |
# |    ep_len_mean     | 1.79e+03 |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 672      |
# |    fps             | 243      |
# |    time_elapsed    | 1869     |
# |    total_timesteps | 454666   |
# | train/             |          |
# |    actor_loss      | -0.565   |
# |    critic_loss     | 0.000386 |
# |    n_updates       | 444665   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0477   |
# | rollout/           |          |
# |    ep_len_mean     | 1.94e+03 |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 676      |
# |    fps             | 243      |
# |    time_elapsed    | 1945     |
# |    total_timesteps | 473334   |
# | train/             |          |
# |    actor_loss      | -0.589   |
# |    critic_loss     | 0.000274 |
# |    n_updates       | 463333   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0479   |
# | rollout/           |          |
# |    ep_len_mean     | 2.19e+03 |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 243      |
# |    time_elapsed    | 2062     |
# |    total_timesteps | 501716   |
# | train/             |          |
# |    actor_loss      | -0.56    |
# |    critic_loss     | 0.000491 |
# |    n_updates       | 491715   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0486   |
# | rollout/           |          |
# |    ep_len_mean     | 2.56e+03 |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 684      |
# |    fps             | 243      |
# |    time_elapsed    | 2226     |
# |    total_timesteps | 541716   |
# | train/             |          |
# |    actor_loss      | -0.655   |
# |    critic_loss     | 0.0005   |
# |    n_updates       | 531715   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0488   |
# | rollout/           |          |
# |    ep_len_mean     | 2.79e+03 |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 688      |
# |    fps             | 243      |
# |    time_elapsed    | 2336     |
# |    total_timesteps | 567873   |
# | train/             |          |
# |    actor_loss      | -0.579   |
# |    critic_loss     | 0.000784 |
# |    n_updates       | 557872   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0497   |
# | rollout/           |          |
# |    ep_len_mean     | 3.09e+03 |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 692      |
# |    fps             | 242      |
# |    time_elapsed    | 2475     |
# |    total_timesteps | 601288   |
# | train/             |          |
# |    actor_loss      | -0.634   |
# |    critic_loss     | 0.000293 |
# |    n_updates       | 591287   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0499   |
# | rollout/           |          |
# |    ep_len_mean     | 3.27e+03 |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 696      |
# |    fps             | 242      |
# |    time_elapsed    | 2566     |
# |    total_timesteps | 623221   |
# | train/             |          |
# |    actor_loss      | -0.666   |
# |    critic_loss     | 0.000472 |
# |    n_updates       | 613220   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0499   |
# | rollout/           |          |
# |    ep_len_mean     | 3.23e+03 |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 242      |
# |    time_elapsed    | 2595     |
# |    total_timesteps | 630049   |
# | train/             |          |
# |    actor_loss      | -0.55    |
# |    critic_loss     | 0.000692 |
# |    n_updates       | 620048   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0502   |
# | rollout/           |          |
# |    ep_len_mean     | 3.37e+03 |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 704      |
# |    fps             | 242      |
# |    time_elapsed    | 2673     |
# |    total_timesteps | 648569   |
# | train/             |          |
# |    actor_loss      | -0.637   |
# |    critic_loss     | 0.000492 |
# |    n_updates       | 638568   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0504   |
# | rollout/           |          |
# |    ep_len_mean     | 3.53e+03 |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 241      |
# |    time_elapsed    | 2769     |
# |    total_timesteps | 667574   |
# | train/             |          |
# |    actor_loss      | -0.584   |
# |    critic_loss     | 0.0003   |
# |    n_updates       | 657573   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0509   |
# | rollout/           |          |
# |    ep_len_mean     | 3.89e+03 |
# |    ep_rew_mean     | 221      |
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 224      |
# |    time_elapsed    | 3141     |
# |    total_timesteps | 706429   |
# | train/             |          |
# |    actor_loss      | -0.584   |
# |    critic_loss     | 0.000414 |
# |    n_updates       | 696428   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.051    |
# | rollout/           |          |
# |    ep_len_mean     | 3.82e+03 |
# |    ep_rew_mean     | 217      |
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 220      |
# |    time_elapsed    | 3263     |
# |    total_timesteps | 719339   |
# | train/             |          |
# |    actor_loss      | -0.558   |
# |    critic_loss     | 0.0007   |
# |    n_updates       | 709338   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0512   |
# | rollout/           |          |
# |    ep_len_mean     | 3.91e+03 |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 215      |
# |    time_elapsed    | 3401     |
# |    total_timesteps | 734115   |
# | train/             |          |
# |    actor_loss      | -0.603   |
# |    critic_loss     | 0.000255 |
# |    n_updates       | 724114   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0512   |
# | rollout/           |          |
# |    ep_len_mean     | 3.86e+03 |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 214      |
# |    time_elapsed    | 3454     |
# |    total_timesteps | 739755   |
# | train/             |          |
# |    actor_loss      | -0.608   |
# |    critic_loss     | 0.000732 |
# |    n_updates       | 729754   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0511   |
# | rollout/           |          |
# |    ep_len_mean     | 3.86e+03 |
# |    ep_rew_mean     | 218      |
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 213      |
# |    time_elapsed    | 3481     |
# |    total_timesteps | 742691   |
# | train/             |          |
# |    actor_loss      | -0.701   |
# |    critic_loss     | 0.000212 |
# |    n_updates       | 732690   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0511   |
# | rollout/           |          |
# |    ep_len_mean     | 3.87e+03 |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 211      |
# |    time_elapsed    | 3538     |
# |    total_timesteps | 748769   |
# | train/             |          |
# |    actor_loss      | -0.583   |
# |    critic_loss     | 0.000335 |
# |    n_updates       | 738768   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0513   |
# | rollout/           |          |
# |    ep_len_mean     | 3.96e+03 |
# |    ep_rew_mean     | 224      |
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 207      |
# |    time_elapsed    | 3673     |
# |    total_timesteps | 763070   |
# | train/             |          |
# |    actor_loss      | -0.563   |
# |    critic_loss     | 0.000577 |
# |    n_updates       | 753069   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0512   |
# | rollout/           |          |
# |    ep_len_mean     | 3.94e+03 |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 206      |
# |    time_elapsed    | 3728     |
# |    total_timesteps | 768970   |
# | train/             |          |
# |    actor_loss      | -0.59    |
# |    critic_loss     | 0.000624 |
# |    n_updates       | 758969   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0512   |
# | rollout/           |          |
# |    ep_len_mean     | 3.98e+03 |
# |    ep_rew_mean     | 225      |
# | time/              |          |
# |    episodes        | 744      |
# |    fps             | 204      |
# |    time_elapsed    | 3791     |
# |    total_timesteps | 775728   |
# | train/             |          |
# |    actor_loss      | -0.614   |
# |    critic_loss     | 0.000436 |
# |    n_updates       | 765727   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0514   |
# | rollout/           |          |
# |    ep_len_mean     | 4.05e+03 |
# |    ep_rew_mean     | 230      |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 202      |
# |    time_elapsed    | 3894     |
# |    total_timesteps | 786712   |
# | train/             |          |
# |    actor_loss      | -0.6     |
# |    critic_loss     | 0.00022  |
# |    n_updates       | 776711   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0515   |
# | rollout/           |          |
# |    ep_len_mean     | 4.11e+03 |
# |    ep_rew_mean     | 234      |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 199      |
# |    time_elapsed    | 4010     |
# |    total_timesteps | 799043   |
# | train/             |          |
# |    actor_loss      | -0.659   |
# |    critic_loss     | 0.000383 |
# |    n_updates       | 789042   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0515   |
# | rollout/           |          |
# |    ep_len_mean     | 4.01e+03 |
# |    ep_rew_mean     | 227      |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 198      |
# |    time_elapsed    | 4061     |
# |    total_timesteps | 804502   |
# | train/             |          |
# |    actor_loss      | -0.584   |
# |    critic_loss     | 0.000401 |
# |    n_updates       | 794501   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0514   |
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | 226      |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 196      |
# |    time_elapsed    | 4120     |
# |    total_timesteps | 810723   |
# | train/             |          |
# |    actor_loss      | -0.558   |
# |    critic_loss     | 0.00198  |
# |    n_updates       | 800722   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0515   |
# | rollout/           |          |
# |    ep_len_mean     | 3.93e+03 |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 195      |
# |    time_elapsed    | 4191     |
# |    total_timesteps | 818254   |
# | train/             |          |
# |    actor_loss      | -0.592   |
# |    critic_loss     | 0.0003   |
# |    n_updates       | 808253   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0516   |
# | rollout/           |          |
# |    ep_len_mean     | 3.99e+03 |
# |    ep_rew_mean     | 226      |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 192      |
# |    time_elapsed    | 4335     |
# |    total_timesteps | 833622   |
# | train/             |          |
# |    actor_loss      | -0.621   |
# |    critic_loss     | 0.000717 |
# |    n_updates       | 823621   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0517   |
# | rollout/           |          |
# |    ep_len_mean     | 3.99e+03 |
# |    ep_rew_mean     | 226      |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 188      |
# |    time_elapsed    | 4524     |
# |    total_timesteps | 853701   |
# | train/             |          |
# |    actor_loss      | -0.62    |
# |    critic_loss     | 0.000314 |
# |    n_updates       | 843700   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0517   |
# | rollout/           |          |
# |    ep_len_mean     | 3.92e+03 |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 186      |
# |    time_elapsed    | 4635     |
# |    total_timesteps | 865453   |
# | train/             |          |
# |    actor_loss      | -0.601   |
# |    critic_loss     | 0.000444 |
# |    n_updates       | 855452   |
# ---------------------------------
# ---------------------------------
# | reward             | 0.0516   |
# | rollout/           |          |
# |    ep_len_mean     | 3.8e+03  |
# |    ep_rew_mean     | 214      |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 184      |
# |    time_elapsed    | 4793     |
# |    total_timesteps | 882188   |
# | train/             |          |
# |    actor_loss      | -0.62    |
# |    critic_loss     | 0.000334 |
# |    n_updates       | 872187   |
# ---------------------------------
# Batch size 1 total time: 82.0 minutes, 41.48152208328247 seconds

# %%
obs, _ = env.reset(seed = 1)

# Take trained agent and loop over environment
i_sd = []
i_sq = []
omegas = []
i_f = []
torque_ref = []
action_stored = []
rewards_stored = []
# obs = ["i_sd", "i_sq", "omega", "i_e", "cos(epsilon)", "sin(epsilon)"], Tref, 3 actions

for i in range(10000):
    action, _states = agent.predict(obs, deterministic=True)
    obs, rewards, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    i_sd_idx = obs[0]
    i_sq_idx = obs[1]
    omega_idx = obs[2]
    i_f_idx = obs[3]
    torque_ref_idx = obs[-4]
    action_idx = obs[-3:]

    i_sd.append(i_sd_idx)
    i_sq.append(i_sq_idx)
    omegas.append(omega_idx)
    i_f.append(i_f_idx)
    torque_ref.append(torque_ref_idx)
    action_stored.append(action_idx)
    
    rewards_stored.append(rewards)

    if done:
        obs,_ = env.reset(seed = 1)

action_record = np.array(action_stored)
rewards_record = np.array(rewards_stored)

# %%
motor_parameter = {
        'p': 2,
        'l_d': 3.78e-3,
        'l_q': 1.21e-3,
        'l_m': 40e-3, 
        'l_e': 870e-3,
        'j_rotor': 0.3883,
        'r_s': 123e-3,
        'r_e': 15.6,
        'k': 0.057,
    }

Supplied_Umax = 100
supp_uf = 200
real_usd = action_record[:,0] * Supplied_Umax
real_usq = action_record[:,1] * Supplied_Umax
real_uf = action_record[:,2] * supp_uf
Real_U = np.sqrt(real_usd**2 + real_usq**2) 

Supplied_Imax = np.array([31.25])
Supplied_Ifmax = np.array([6.25])
real_isd = i_sd * Supplied_Imax
real_isq = i_sq * Supplied_Imax
real_if = i_f * Supplied_Ifmax
Real_I = np.sqrt(real_isd**2 + real_isq**2)

# torque knowledge is not available to the agent, so manually calculated for visualization purpose
T_inter = np.zeros(len(i_sd))
T_relu = np.zeros(len(i_sd))
T_em = np.zeros(len(i_sd))

for i in range(len(i_sd)):
    T_inter[i] = motor_parameter['l_m'] * real_if[i] * real_isq[i]
    T_relu[i] = (motor_parameter['l_d'] - motor_parameter['l_q']) * real_isd[i] * real_isq[i]
    T_em[i] = (3/2) * motor_parameter['p'] * (T_inter[i] + T_relu[i])

T_max = np.array([20])
real_T  = T_em # physical value
real_Tref = torque_ref * T_max
Error = real_Tref - real_T

T_nom = T_em / T_max # nominal value

S_max = np.array([7e+3*np.pi/30])
real_S = omegas * S_max

# Reward Manually, for different validation profile
is_nominal = 0.8
T_lim = 1
gamma = 0.9
R_manual = np.zeros(len(i_sd))
T_E_check = np.zeros(len(i_sd))
i_s_app = np.zeros(len(i_sd))

for rr in range(len(i_sd)):
    T_E_check[rr] = abs(torque_ref[rr] - T_nom[rr])
    i_s_app[rr] = np.sqrt(i_sd[rr]**2 + i_sq[rr]**2)
    if (T_E_check[rr] > 0.1):
        R_manual[rr] = (1- T_E_check[rr]/(2*T_lim)) * ((1- gamma)/2)
    
    elif (T_E_check[rr] < 0.1):
        R_manual[rr] = (1-i_s_app[rr])*((1- gamma)/2) + ((1- gamma)/2)

# Efficiency Calculation
P_stator = (3/2) * (real_usd*real_isd + real_usq*real_isq) # power from stator side
P_rotor = real_uf * real_if # power from rotor side
P_ele = P_stator + P_rotor # total electrical power 

# losses included, just for some more insight, not to utilize
Ps_loss = (3/2) * Real_I**2 * motor_parameter['r_s'] # stator loss
Pr_loss = real_if**2 * motor_parameter['r_e'] # rotor loss
P_losses = Ps_loss + Pr_loss # total loss

P_mech = real_T * real_S # mechanical power 

P_total = P_ele - P_mech - P_losses

# From Losses, just for some more insight, not to utilize
eff = np.zeros(len(P_mech))
for i in range(len(P_mech)):
    if (torque_ref[i] == 0): # motor
        eff[i] = 0

    elif (P_mech[i] > 0): # motor
        eff[i] = (abs(P_mech[i])/ (P_losses[i] + abs(P_mech[i])))

    elif (P_losses[i] > abs(P_mech[i])): # braking
        eff[i] = (P_losses[i] - abs(P_mech[i]))/ P_losses[i]

    elif (P_mech[i] < 0): # generator
        # eff[i] = abs(((-P_losses[i] + abs(P_mech[i]))/ (P_losses[i] + abs(P_mech[i]))))
        eff[i] = abs((P_mech[i] + P_losses[i]) / P_mech[i])

# From input vs output, this will be used for further cases
eff2 = np.zeros(len(P_mech))
for j in range(len(P_mech)):
    if (torque_ref[j] == 0): # no torque, no eff
        eff2[j] = 0
    elif (P_ele[j] > 0 and P_mech[j] < 0) or (P_ele[j] < 0 and P_mech[j] > 0): # breaking cases, not considered becasue input output power unclear
        eff2[j] = 0
    else:
        eff2[j] = max([0, min([1, min([abs(P_ele[j]), abs(P_mech[j])]) / max([abs(P_ele[j]), abs(P_mech[j])])])])


# For MTPC method, just to get some more insight, not important
i_f_num = np.array([5]) #nominal value
i_stator = 25 # nominal value

p = motor_parameter['p']
l_d = motor_parameter['l_d']
l_q = motor_parameter['l_q']
l_M = 3 / 2 * motor_parameter['k'] * motor_parameter['l_m']
i_F_num = 2 / 3 / motor_parameter['k'] * i_f_num

var1 = -l_M * i_F_num
var2 = np.sqrt(l_M**2 * i_F_num**2 + 32 * i_stator**2 * (l_d - l_q)**2) 
var3 = 8 * i_stator * (l_d - l_q)

theta1 = np.zeros(len(i_f_num)) # MPTC angle

for i in range(len(i_f_num)):
    theta1[i] = np.arccos((var1[i] + var2[i])/ var3)

i_sd_num = i_stator * np.cos(theta1)
i_sq_num = i_stator * np.sin(theta1)
i_sq_negat = -i_stator * np.sin(theta1)

Tem_num = np.zeros(len(i_f_num))
Tem_negat = np.zeros(len(i_f_num))

for j in range(len(i_f_num)):
    Tem_num[j] = (3/2) * p * (l_M * i_F_num[j] * i_sq_num[j] + (l_d - l_q) * i_sd_num[j] * i_sq_num[j]) # positive torque
    Tem_negat[j] = (3/2) * p * (l_M * i_F_num[j] * i_sq_negat[j] + (l_d - l_q) * i_sd_num[j] * i_sq_negat[j]) # negative torque

Tem_pos_nom = Tem_num/20 # nominal 
Tem_neg_nom = Tem_negat/20 # nominal

visual = np.concatenate((np.array(i_f_num).reshape(-1,1), 
                         np.array(i_sd_num).reshape(-1,1), 
                         np.array(i_sq_num).reshape(-1,1), 
                         np.array(Tem_num).reshape(-1,1), 
                         np.array(Tem_negat).reshape(-1,1)), axis = 1)

# print(f"    i_f         i_sd       i_sq         Tem         Tem_neg \n {visual}")

# Root mean square error
J_T = 0
count = len(i_sd)
for i in range(count):
    J_T = J_T + ((torque_ref[i] - T_nom[i]) ** 2)

J_T = J_T/ count

print(f"Mean Square Error: \n {J_T}")
# Out:
# Mean Square Error:
#  0.021478040734932285
# <ipython-input-15-aa781605e8ca>:105: RuntimeWarning: invalid value encountered in scalar divide
#   eff2[j] = max([0, min([1, min([abs(P_ele[j]), abs(P_mech[j])]) / max([abs(P_ele[j]), abs(P_mech[j])])])])

# %%
# time_points = range(len(i_sd))
sampling = 1e-4
time_points = range(len(i_sd))
time_duration = np.arange(0, len(i_sd), 1000)
time_sec = (time_duration * sampling).round(2)

import seaborn as sns
sns.set_theme(context='notebook', style='white', palette='deep', font='Times New Roman', font_scale=1, color_codes=True, rc={'axes.linewidth': 2, 'grid.linewidth': 2})
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 12), sharex=True)

ax1.plot(time_points, i_sd, label='i_sd', color = 'red')
ax1.plot(time_points, i_sq, label='i_sq', color = 'green')
ax1.plot(time_points, i_f, label = 'i_f', color = 'blue')
ax1.set_ylabel(r'Current $[\frac{i}{i_{\text{max}}}]$')
ax1.legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol = 3)
ax1.grid()

ax2.plot(time_points, T_nom, label='T', color = 'red')
ax2.plot(time_points, torque_ref, label='T_ref', color = 'green')
# ax2.fill_between(time_points, Tem_pos_nom, Tem_neg_nom, label = 'Available Torque Region', color = 'skyblue')
ax2.set_ylabel(r'Torque $[\frac{T}{T_{\text{max}}}]$')
ax2.legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol=3)
ax2.grid()

ax3.plot(time_points, omegas, label = r'$\omega$', color = 'red')
ax3.set_ylabel(r'Speed $[\frac{\omega}{\omega_{\text{max}}}]$')
ax3.legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol = 1)
ax3.grid()

ax4.plot(time_points, action_record[:,0], label='u_sd', color='red')
ax4.plot(time_points, action_record[:,1], label='u_sq', color='green')
ax4.plot(time_points, action_record[:,2], label='u_f', color='blue')
ax4.set_ylabel(r'Voltage $[\frac{u}{u_{\text{max}}}]$')
ax4.set_xlabel('Time step')
# ax4.set_ylim([-1,1])
ax4.set_xlim([0, len(i_sd)])
ax4.legend(loc='upper left', bbox_to_anchor=(0, -0.1),
          fancybox=True, shadow=True, ncol = 3)
ax4.grid()
# ax5.set_ylim([-1.5, 1.5])
# Adjust layout
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10), sharex=True)
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=fig_size, sharex=True)

axes[0,0].plot(time_points, real_usd, label=r'$u_{\mathrm{sd}}$', color='red')
axes[0,0].plot(time_points, real_usq, label=r'$u_{\mathrm{sq}}$', color='green')
axes[0,0].plot(time_points, real_uf, label=r'$u_{\mathrm{f}}$', color='blue')
axes[0,0].set_ylabel(r'$u \,\, / \,\, \mathrm{V}$', fontsize = 16)
axes[0,0].legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol = 3, fontsize = 16)
axes[0,0].tick_params(axis='y', labelsize=14) 
axes[0,0].grid()

axes[1,0].plot(time_points, real_isd, label=r'$i_{\mathrm{sd}}$', color = 'red')
axes[1,0].plot(time_points, real_isq, label=r'$i_{\mathrm{sq}}$', color = 'green')
axes[1,0].plot(time_points, real_if, label = r'$i_{\mathrm{f}}$', color = 'blue')
axes[1,0].set_ylabel(r'$i \,\, / \,\, \mathrm{A}$', fontsize = 16)
axes[1,0].legend(loc='lower left', fancybox=True, shadow=True, ncol = 3, fontsize = 16)
axes[1,0].tick_params(axis='y', labelsize=14) 
axes[1,0].grid()
axes[1,0].set_xlabel(r'$t \,\, / \,\, \mathrm{s}$', fontsize = 16)
axes[1,0].tick_params(axis='x', labelsize=14) 

# Second subplot for i_qs and i_qs_ref
axes[0,1].plot(time_points, real_T, label=r'$T$', color = 'red')
axes[0,1].plot(time_points, real_Tref, label=r'$T^*$', color = 'green')
axes[0,1].fill_between(time_points, Tem_num, Tem_negat, label = r'$\text{Available Torque Region}$', color = 'skyblue')
axes[0,1].set_ylabel(r'$T \,\, / \,\, \mathrm{Nm}$', fontsize = 16)
axes[0,1].legend(loc='upper left', bbox_to_anchor=(0, 0),
          fancybox=True, shadow=True, ncol=3, fontsize = 16)
axes[0,1].tick_params(axis='y', labelsize=14) 
axes[0,1].grid()

axes[1,1].plot(time_points, Error, label = r'$T_{\mathrm{Error}}$', color = 'red')
# axes[1,1].fill_between(time_points, Tem_num, Tem_negat, label = r'$\text{Available Torque Region}$', color = 'skyblue')
axes[1,1].fill_between(time_points, -2, 2, facecolor='none', edgecolor='black', linewidth = 2, label=r'$\text{Tolerance}$')
axes[1,1].set_ylabel(r'$T_{\mathrm{error}} \,\, / \,\, \mathrm{Nm}$', fontsize = 16)
axes[1,1].legend(loc='lower left', fancybox=True, shadow=True, ncol=3, fontsize = 16)
axes[1,1].tick_params(axis='y', labelsize=14) 
axes[1,1].grid()
axes[1,1].set_xlabel(r'$t \,\, / \,\, \mathrm{s}$', fontsize = 16)
axes[1,1].tick_params(axis='x', labelsize=14) 
axes[1,1].set_xlim([0, len(i_sd)])
axes[1,1].set_xticks(time_duration, time_sec)

# plt.savefig('/Users/nyinyia/Documents/GIT/testing.pdf', format='pdf', bbox_inches='tight')
plt.tight_layout()
plt.show()
